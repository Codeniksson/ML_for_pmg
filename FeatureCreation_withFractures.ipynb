# %% [markdown]
# # Feature generation from mesh and fractures data
#
# ⚠️ **Important:** This notebook is **Step 2**. You must complete **Step 1** before running it.
#
# ---
#
# ### Pipeline Overview
#
# 1. **Step 1 — Run inside the PorePy environment**
#    **Input:** Model setup and fracture configuration.
#    **Output:**
#    - Mesh files: `mesh2d_Xfr_id.msh`
#    - Fracture metadata: `mesh_meta_id.json`
#    - Solver log: `solver_times.csv` (convergence, solve time, etc.)
#
#    **Example:**
#    `D:/MLpmg/Data_Large4` contains 4000 meshes, matching fracture files with IDs in `0.4d` format, and one `solver_times.csv`.
#
# ---
#
# 2. **Step 2 — Create the feature dataset** *(this notebook)*
#    **Input:**
#    - Mesh files `*.msh`
#    - Fracture metadata `*.json`
#    - Solver log `solver_times.csv`
#
#    **Output:**
#    - Feature table `mesh_features.csv` combining mesh geometry, fracture stats, and solver outcomes.
#
#    **Usage example:**
#    ```python
#    from dataset_builder import MeshFeatureDatasetBuilder
#
#    builder = MeshFeatureDatasetBuilder(
#        mesh_dir="D:/ML4pmg/Data_Large4/",
#        solver_csv="D:/ML4pmg/Data_Large4/solver_times.csv",
#        output_csv="D:/ML4pmg/Data_Large4/mesh_features.csv",
#        log_transform=True
#    )
#
# ---
#
# 3. **Step 3 – Run `Clf_and_Reg_Combined.ipynb`**
#    - Train models and generate predictions.
#    - Compare results against baseline and clairvoyant approaches.

# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import meshio
import json

from sklearn.decomposition import PCA
import seaborn as sns
from scipy.spatial import cKDTree

# %%
df = pd.read_csv("D:/ML4pmg/Data_Large4/solver_times.csv") # Data_Large, or Data_Large2
df.tail()
# Out:
#        Mesh #  Fractures #  Combination # KSP Type  PC Mass PC Interface  \
# 71995    3999           49             13    tfqmr      sor          ilu
# 71996    3999           49             14    tfqmr   jacobi          ilu
# 71997    3999           49             15    tfqmr  bjacobi          ilu
# 71998    3999           49             16    tfqmr      asm          ilu
# 71999    3999           49             17    tfqmr     gamg          ilu
#
#        Converged  Krylov Iters  Construction Time (s)  Solve Time (s)  \
# 71995      False           NaN                    NaN             NaN
# 71996      False           NaN                    NaN             NaN
# 71997      False           NaN                    NaN             NaN
# 71998      False           NaN                    NaN             NaN
# 71999       True         180.0               0.149009        0.887573
#
#        Total Time (s)  Tic Toc Time (s)           Solver Label  \
# 71995             NaN               NaN      tfqmr + sor + ilu
# 71996             NaN               NaN   tfqmr + jacobi + ilu
# 71997             NaN               NaN  tfqmr + bjacobi + ilu
# 71998             NaN               NaN      tfqmr + asm + ilu
# 71999        1.036582          5.668525     tfqmr + gamg + ilu
#
#        Adjusted Time (s)
# 71995           4.850165
# 71996           4.850165
# 71997           4.850165
# 71998           4.850165
# 71999           1.036582

# %%
len(df)/18
# Out:
# 4000.0

# %% [markdown]
# ### Help Functions

# %%
def compute_edge_lengths(p0, p1, p2):
    a = np.linalg.norm(p1 - p0)
    b = np.linalg.norm(p2 - p1)
    c = np.linalg.norm(p0 - p2)
    return a, b, c

def compute_signed_area(p0, p1, p2):
    return 0.5 * ((p1[0] - p0[0]) * (p2[1] - p0[1]) - (p2[0] - p0[0]) * (p1[1] - p0[1]))

def compute_rms_edge(a, b, c):
    return np.sqrt((a ** 2 + b ** 2 + c ** 2) / 3)

def compute_internal_angles(p0, p1, p2):
    def angle(a, b, c):
        ba = a - b
        bc = c - b
        cosa = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
        return np.degrees(np.arccos(np.clip(cosa, -1, 1)))
    return angle(p1, p0, p2), angle(p0, p1, p2), angle(p0, p2, p1)

def compute_triangle_center(p0, p1, p2):
    return (p0 + p1 + p2) / 3

def compute_volume_length_metric(signed_area, rms_edge):
    return (4 * np.sqrt(3) / 3) * signed_area / (rms_edge ** 2) if rms_edge > 0 else 0

def compute_triangle_features(p0, p1, p2):
    a, b, c = compute_edge_lengths(p0, p1, p2)
    signed_area = compute_signed_area(p0, p1, p2)
    area = abs(signed_area)
    rms_edge = compute_rms_edge(a, b, c)
    vol_length = compute_volume_length_metric(signed_area, rms_edge)
    angles = compute_internal_angles(p0, p1, p2)
    center = compute_triangle_center(p0, p1, p2)

    return {
        "area": area,
        "signed_area": signed_area,
        "rms_edge": rms_edge,
        "volume_length_metric": vol_length,
        "min_angle": min(angles),
        "max_angle": max(angles),
        "center": center
    }

# %% [markdown]
# # 📊 Feature Summary for Mesh and Fracture-Based Dataset
#
# All array-based features are summarized with the following statistics:
# - `mean`
# - `median`
# - `std`
# - `min`, `max`
# - `5pct`, `95pct`
#
# The corresponding column names follow the pattern:
# `<feature>_<stat>`
# e.g., `rms_edge_mean`, `length_95pct`, etc.
#
# ---
#
# ## 🧱 Mesh-Based Features
#
# | Feature Group            | Description                                          |
# |--------------------------|------------------------------------------------------|
# | `area_*`                 | Triangle area                                        |
# | `signed_area_*`          | Signed triangle area (for orientation checks)        |
# | `rms_edge_*`             | Root-mean-square of triangle edge lengths            |
# | `volume_length_metric_*` | Shape quality metric: volume-to-length ratio         |
# | `min_angle_*`            | Minimum internal angle per triangle                  |
# | `max_angle_*`            | Maximum internal angle per triangle                  |
# | `grading_ratio_*`        | Ratio of neighboring triangle sizes (element grading)|
# | `n_elements`             | Total number of triangles in the mesh                |
# | `n_nodes`                | Total number of mesh vertices                        |
# | `n_fractures`            | Number of fractures in the mesh (from metadata or CSV)|
#
# ---
#
# ## 🌐 Fracture-Based Features
#
# | Feature Group              | Description                                               |
# |----------------------------|-----------------------------------------------------------|
# | `length_*`                 | Lengths of all fractures                                  |
# | `orientation_*`            | Orientation angles of fractures (in radians)              |
# | `domain_span_x`            | Total horizontal extent (x-range) of all fracture endpoints |
# | `domain_span_y`            | Total vertical extent (y-range) of all fracture endpoints |
# | `fracture_density`         | Total fracture length divided by domain area              |
# | `n_fractures`              | Number of fractures in the domain                         |
# | `mortar_cells_2d_1d`       | Number of mortar cells between matrix (2D) and fractures (1D) |
# | `mortar_cells_1d_0d`       | Number of mortar cells at fracture tips (1D–0D)           |
# | `mortar_cells_total`       | Total mortar cells (`2d-1d` + `1d-0d`)                    |
# | `mortar_cells_per_fracture`| Average number of 2d–1d mortar cells per fracture         |

# %% [markdown]
# ### Main Class to build the dataset
#
# Loop over all meshes in the folder and create the DataFrame of features, add labeles and number of fractures from solve_times.csv

# %%
class MeshFeatureDatasetBuilder:
    def __init__(self, mesh_dir, solver_csv, output_csv, log_transform=True):
        self.mesh_dir = mesh_dir
        self.solver_df = pd.read_csv(solver_csv)
        self.output_csv = output_csv
        self.log_transform = log_transform

        self.meta_dir = mesh_dir  # NEW
    
        
    

    def prepare_solver_tables(self):
        self.solver_times = self.solver_df.pivot_table(
            index='Mesh #', columns='Combination #', values='Adjusted Time (s)'
        ).sort_index()

        self.solver_convergence = self.solver_df.pivot_table(
            index='Mesh #', columns='Combination #', values='Converged'
        ).sort_index()

        self.fracture_counts = self.solver_df.groupby('Mesh #')['Fractures #'].first().to_dict()

    def summarize_array(self, arr, name):
        return {
            f"{name}_mean": np.mean(arr),
            f"{name}_median": np.median(arr),
            f"{name}_std": np.std(arr),
            f"{name}_5pct": np.percentile(arr, 5),
            f"{name}_95pct": np.percentile(arr, 95),
            f"{name}_min": np.min(arr),
            f"{name}_max": np.max(arr)
        }

    def compute_features_for_mesh(self, mesh_path, mesh_id):
        mesh = meshio.read(mesh_path)
        coords = mesh.points[:, :2]
        triangles = mesh.cells_dict.get("triangle")
        if triangles is None:
            raise ValueError(f"No triangles in {mesh_path}")

        areas, signed_areas, rms_edges, vol_lengths, min_angles, max_angles, centers = [], [], [], [], [], [], []
        for tri in triangles:
            pts = [coords[i] for i in tri]
            feats = compute_triangle_features(*pts)
            areas.append(feats["area"])
            signed_areas.append(feats["signed_area"])
            rms_edges.append(feats["rms_edge"])
            vol_lengths.append(feats["volume_length_metric"])
            min_angles.append(feats["min_angle"])
            max_angles.append(feats["max_angle"])
            centers.append(feats["center"])

        # Grading ratios
        tree = cKDTree(centers)
        grading_ratios = []
        for i, center in enumerate(centers):
            _, idxs = tree.query(center, k=2)
            h1, h2 = rms_edges[i], rms_edges[idxs[1]]
            grading_ratios.append(max(h1 / h2, h2 / h1))

        feature_dict = {
            "mesh_name": os.path.basename(mesh_path),
            "mesh_id": mesh_id,
            "n_elements": len(triangles),
            "n_nodes": len(coords),
            "n_fractures": self.fracture_counts.get(mesh_id, -1)
        }

        for arr, name in [
            (areas, "area"),
            (signed_areas, "signed_area"),
            (rms_edges, "rms_edge"),
            (vol_lengths, "volume_length_metric"),
            (min_angles, "min_angle"),
            (max_angles, "max_angle"),
            (grading_ratios, "grading_ratio")
        ]:
            feature_dict.update(self.summarize_array(arr, name))

        return feature_dict

    def extract_fracture_features(self, mesh_id):
        json_path = os.path.join(self.meta_dir, f"mesh_meta_{mesh_id:04d}.json")
        
        with open(json_path) as f:
            meta = json.load(f)

        fracs = meta["fractures"]
        n_fractures = len(fracs)
        lengths, orientations = [], []

        for frac in fracs:
            x0, y0 = frac[0]
            x1, y1 = frac[1]
            dx, dy = x1 - x0, y1 - y0
            lengths.append(np.hypot(dx, dy))
            orientations.append(np.arctan2(dy, dx))

        bbox = np.array(fracs).reshape(-1, 2)
        x_vals, y_vals = bbox[:, 0], bbox[:, 1]
        span_x = x_vals.max() - x_vals.min()
        span_y = y_vals.max() - y_vals.min()
        area = span_x * span_y
        total_length = np.sum(lengths)

        feat = {
            "n_fractures": n_fractures,
            "domain_span_x": span_x,
            "domain_span_y": span_y,
            "fracture_density": total_length / area if area > 0 else 0,
            "mortar_cells_2d_1d": meta["n_mortar_cells"]["2d-1d"],
            "mortar_cells_1d_0d": meta["n_mortar_cells"]["1d-0d"],
            "mortar_cells_total": meta["n_mortar_cells"]["2d-1d"] + meta["n_mortar_cells"]["1d-0d"],
            "mortar_cells_per_fracture": meta["n_mortar_cells"]["2d-1d"] / n_fractures if n_fractures > 0 else 0,
        }

        feat.update(self.summarize_array(lengths, "length"))
        feat.update(self.summarize_array(orientations, "orientation"))
        return feat



    def extract_features_for_mesh(self, mesh_id):
        mesh_path = os.path.join(self.mesh_dir, f"mesh2d_Xfr_{mesh_id:04d}.msh")
        feature_dict = self.compute_features_for_mesh(mesh_path, mesh_id)

        y_time = self.solver_times.loc[mesh_id].values
        y_conv = self.solver_convergence.loc[mesh_id].values.astype(float)

        if self.log_transform:
            y_time = -np.log(np.abs(y_time) + 1e-6)

        for i, t in enumerate(y_time):
            feature_dict[f"y_time_{i}"] = t
        for i, c in enumerate(y_conv):
            feature_dict[f"y_conv_{i}"] = c

        # Add fracture features from metadata
        if self.meta_dir is not None:
            try:
                fracture_features = self.extract_fracture_features(mesh_id)
                feature_dict.update(fracture_features)
            except Exception as e:
                print(f"⚠️ Failed to extract fracture features for mesh {mesh_id}: {e}")
        return feature_dict      

    def build_dataset(self):
        self.prepare_solver_tables()
        all_data = []
        for mesh_id in self.solver_times.index:  
#        for mesh_id in self.solver_times.index:
            try:
                feats = self.extract_features_for_mesh(mesh_id)
                all_data.append(feats)
                print(f"✅ Processed mesh {mesh_id}")
            except Exception as e:
                print(f"❌ Failed mesh {mesh_id}: {e}")

        df = pd.DataFrame(all_data)
        df.to_csv(self.output_csv, index=False)
        print(f"\n✅ Saved dataset to {self.output_csv}")

# %%
builder = MeshFeatureDatasetBuilder(
    mesh_dir="D:/ML4pmg/Data_Large4/",
    solver_csv="D:/ML4pmg/Data_Large4/solver_times.csv",
    output_csv="D:/ML4pmg/Data_Large4/mesh_features.csv",
    log_transform=True
)

t0 = time.time()
builder.build_dataset()
t1 = time.time()
print(f"Dataset built in {t1 - t0:.2f} seconds")
# Out:
# ✅ Processed mesh 0
#
# ✅ Processed mesh 1
#
# ✅ Processed mesh 2
#
# ✅ Processed mesh 3
#
# ✅ Processed mesh 4
#
# ✅ Processed mesh 5
#
# ✅ Processed mesh 6
#
# ✅ Processed mesh 7
#
# ✅ Processed mesh 8
#
# ✅ Processed mesh 9
#
# ✅ Processed mesh 10
#
# ✅ Processed mesh 11
#
# ✅ Processed mesh 12
#
# ✅ Processed mesh 13
#
# ✅ Processed mesh 14
#
# ✅ Processed mesh 15
#
# ✅ Processed mesh 16
#
# ✅ Processed mesh 17
#
# ✅ Processed mesh 18
#
# ✅ Processed mesh 19
#
# ✅ Processed mesh 20
#
# ✅ Processed mesh 21
#
# ✅ Processed mesh 22
#
# ✅ Processed mesh 23
#
# ✅ Processed mesh 24
#
# ✅ Processed mesh 25
#
# ✅ Processed mesh 26
#
# ✅ Processed mesh 27
#
# ✅ Processed mesh 28
#
# ✅ Processed mesh 29
#
# ✅ Processed mesh 30
#
# ✅ Processed mesh 31
#
# ✅ Processed mesh 32
#
# ✅ Processed mesh 33
#
# ✅ Processed mesh 34
#
# ✅ Processed mesh 35
#
# ✅ Processed mesh 36
#
# ✅ Processed mesh 37
#
# ✅ Processed mesh 38
#
# ✅ Processed mesh 39
#
# ✅ Processed mesh 40
#
# ✅ Processed mesh 41
#
# ✅ Processed mesh 42
#
# ✅ Processed mesh 43
#
# ✅ Processed mesh 44
#
# ✅ Processed mesh 45
#
# ✅ Processed mesh 46
#
# ✅ Processed mesh 47
#
# ✅ Processed mesh 48
#
# ✅ Processed mesh 49
#
# ✅ Processed mesh 50
#
# ✅ Processed mesh 51
#
# ✅ Processed mesh 52
#
# ✅ Processed mesh 53
#
# ✅ Processed mesh 54
#
# ✅ Processed mesh 55
#
# ✅ Processed mesh 56
#
# ✅ Processed mesh 57
#
# ✅ Processed mesh 58
#
# ✅ Processed mesh 59
#
# ✅ Processed mesh 60
#
# ✅ Processed mesh 61
#
# ✅ Processed mesh 62
#
# ✅ Processed mesh 63
#
# ✅ Processed mesh 64
#
# ✅ Processed mesh 65
#
# ✅ Processed mesh 66
#
# ✅ Processed mesh 67
#
# ✅ Processed mesh 68
#
# ✅ Processed mesh 69
#
# ✅ Processed mesh 70
#
# ✅ Processed mesh 71
#
# ✅ Processed mesh 72
#
# ✅ Processed mesh 73
#
# ✅ Processed mesh 74
#
# ✅ Processed mesh 75
#
# ✅ Processed mesh 76
#
# ✅ Processed mesh 77
#
# ✅ Processed mesh 78
#
# ✅ Processed mesh 79
#
# ✅ Processed mesh 80
#
# ✅ Processed mesh 81
#
# ✅ Processed mesh 82
#
# ✅ Processed mesh 83
#
# ✅ Processed mesh 84
#
# ✅ Processed mesh 85
#
# ✅ Processed mesh 86
#
# ✅ Processed mesh 87
#
# ✅ Processed mesh 88
#
# ✅ Processed mesh 89
#
# ✅ Processed mesh 90
#
# ✅ Processed mesh 91
#
# ✅ Processed mesh 92
#
# ✅ Processed mesh 93
#
# ✅ Processed mesh 94
#
# ✅ Processed mesh 95
#
# ✅ Processed mesh 96
#
# ✅ Processed mesh 97
#
# ✅ Processed mesh 98
#
# ✅ Processed mesh 99
#
# ✅ Processed mesh 100
#
# ✅ Processed mesh 101
#
# ✅ Processed mesh 102
#
# ✅ Processed mesh 103
#
# ✅ Processed mesh 104
#
# ✅ Processed mesh 105
#
# ✅ Processed mesh 106
#
# ✅ Processed mesh 107
#
# ✅ Processed mesh 108
#
# ✅ Processed mesh 109
#
# ✅ Processed mesh 110
#
# ✅ Processed mesh 111
#
# ✅ Processed mesh 112
#
# ✅ Processed mesh 113
#
# ✅ Processed mesh 114
#
# ✅ Processed mesh 115
#
# ✅ Processed mesh 116
#
# ✅ Processed mesh 117
#
# ✅ Processed mesh 118
#
# ✅ Processed mesh 119
#
# ✅ Processed mesh 120
#
# ✅ Processed mesh 121
#
# ✅ Processed mesh 122
#
# ✅ Processed mesh 123
#
# ✅ Processed mesh 124
#
# ✅ Processed mesh 125
#
# ✅ Processed mesh 126
#
# ✅ Processed mesh 127
#
# ✅ Processed mesh 128
#
# ✅ Processed mesh 129
#
# ✅ Processed mesh 130
#
# ✅ Processed mesh 131
#
# ✅ Processed mesh 132
#
# ✅ Processed mesh 133
#
# ✅ Processed mesh 134
#
# ✅ Processed mesh 135
#
# ✅ Processed mesh 136
#
# ✅ Processed mesh 137
#
# ✅ Processed mesh 138
#
# ✅ Processed mesh 139
#
# ✅ Processed mesh 140
#
# ✅ Processed mesh 141
#
# ✅ Processed mesh 142
#
# ✅ Processed mesh 143
#
# ✅ Processed mesh 144
#
# ✅ Processed mesh 145
#
# ✅ Processed mesh 146
#
# ✅ Processed mesh 147
#
# ✅ Processed mesh 148
#
# ✅ Processed mesh 149
#
# ✅ Processed mesh 150
#
# ✅ Processed mesh 151
#
# ✅ Processed mesh 152
#
# ✅ Processed mesh 153
#
# ✅ Processed mesh 154
#
# ✅ Processed mesh 155
#
# ✅ Processed mesh 156
#
# ✅ Processed mesh 157
#
# ✅ Processed mesh 158
#
# ✅ Processed mesh 159
#
# ✅ Processed mesh 160
#
# ✅ Processed mesh 161
#
# ✅ Processed mesh 162
#
# ✅ Processed mesh 163
#
# ✅ Processed mesh 164
#
# ✅ Processed mesh 165
#
# ✅ Processed mesh 166
#
# ✅ Processed mesh 167
#
# ✅ Processed mesh 168
#
# ✅ Processed mesh 169
#
# ✅ Processed mesh 170
#
# ✅ Processed mesh 171
#
# ✅ Processed mesh 172
#
# ✅ Processed mesh 173
#
# ✅ Processed mesh 174
#
# ✅ Processed mesh 175
#
# ✅ Processed mesh 176
#
# ✅ Processed mesh 177
#
# ✅ Processed mesh 178
#
# ✅ Processed mesh 179
#
# ✅ Processed mesh 180
#
# ✅ Processed mesh 181
#
# ✅ Processed mesh 182
#
# ✅ Processed mesh 183
#
# ✅ Processed mesh 184
#
# ✅ Processed mesh 185
#
# ✅ Processed mesh 186
#
# ✅ Processed mesh 187
#
# ✅ Processed mesh 188
#
# ✅ Processed mesh 189
#
# ✅ Processed mesh 190
#
# ✅ Processed mesh 191
#
# ✅ Processed mesh 192
#
# ✅ Processed mesh 193
#
# ✅ Processed mesh 194
#
# ✅ Processed mesh 195
#
# ✅ Processed mesh 196
#
# ✅ Processed mesh 197
#
# ✅ Processed mesh 198
#
# ✅ Processed mesh 199
#
# ✅ Processed mesh 200
#
# ✅ Processed mesh 201
#
# ✅ Processed mesh 202
#
# ✅ Processed mesh 203
#
# ✅ Processed mesh 204
#
# ✅ Processed mesh 205
#
# ✅ Processed mesh 206
#
# ✅ Processed mesh 207
#
# ✅ Processed mesh 208
#
# ✅ Processed mesh 209
#
# ✅ Processed mesh 210
#
# ✅ Processed mesh 211
#
# ✅ Processed mesh 212
#
# ✅ Processed mesh 213
#
# ✅ Processed mesh 214
#
# ✅ Processed mesh 215
#
# ✅ Processed mesh 216
#
# ✅ Processed mesh 217
#
# ✅ Processed mesh 218
#
# ✅ Processed mesh 219
#
# ✅ Processed mesh 220
#
# ✅ Processed mesh 221
#
# ✅ Processed mesh 222
#
# ✅ Processed mesh 223
#
# ✅ Processed mesh 224
#
# ✅ Processed mesh 225
#
# ✅ Processed mesh 226
#
# ✅ Processed mesh 227
#
# ✅ Processed mesh 228
#
# ✅ Processed mesh 229
#
# ✅ Processed mesh 230
#
# ✅ Processed mesh 231
#
# ✅ Processed mesh 232
#
# ✅ Processed mesh 233
#
# ✅ Processed mesh 234
#
# ✅ Processed mesh 235
#
# ✅ Processed mesh 236
#
# ✅ Processed mesh 237
#
# ✅ Processed mesh 238
#
# ✅ Processed mesh 239
#
# ✅ Processed mesh 240
#
# ✅ Processed mesh 241
#
# ✅ Processed mesh 242
#
# ✅ Processed mesh 243
#
# ✅ Processed mesh 244
#
# ✅ Processed mesh 245
#
# ✅ Processed mesh 246
#
# ✅ Processed mesh 247
#
# ✅ Processed mesh 248
#
# ✅ Processed mesh 249
#
# ✅ Processed mesh 250
#
# ✅ Processed mesh 251
#
# ✅ Processed mesh 252
#
# ✅ Processed mesh 253
#
# ✅ Processed mesh 254
#
# ✅ Processed mesh 255
#
# ✅ Processed mesh 256
#
# ✅ Processed mesh 257
#
# ✅ Processed mesh 258
#
# ✅ Processed mesh 259
#
# ✅ Processed mesh 260
#
# ✅ Processed mesh 261
#
# ✅ Processed mesh 262
#
# ✅ Processed mesh 263
#
# ✅ Processed mesh 264
#
# ✅ Processed mesh 265
#
# ✅ Processed mesh 266
#
# ✅ Processed mesh 267
#
# ✅ Processed mesh 268
#
# ✅ Processed mesh 269
#
# ✅ Processed mesh 270
#
# ✅ Processed mesh 271
#
# ✅ Processed mesh 272
#
# ✅ Processed mesh 273
#
# ✅ Processed mesh 274
#
# ✅ Processed mesh 275
#
# ✅ Processed mesh 276
#
# ✅ Processed mesh 277
#
# ✅ Processed mesh 278
#
# ✅ Processed mesh 279
#
# ✅ Processed mesh 280
#
# ✅ Processed mesh 281
#
# ✅ Processed mesh 282
#
# ✅ Processed mesh 283
#
# ✅ Processed mesh 284
#
# ✅ Processed mesh 285
#
# ✅ Processed mesh 286
#
# ✅ Processed mesh 287
#
# ✅ Processed mesh 288
#
# ✅ Processed mesh 289
#
# ✅ Processed mesh 290
#
# ✅ Processed mesh 291
#
# ✅ Processed mesh 292
#
# ✅ Processed mesh 293
#
# ✅ Processed mesh 294
#
# ✅ Processed mesh 295
#
# ✅ Processed mesh 296
#
# ✅ Processed mesh 297
#
# ✅ Processed mesh 298
#
# ✅ Processed mesh 299
#
# ✅ Processed mesh 300
#
# ✅ Processed mesh 301
#
# ✅ Processed mesh 302
#
# ✅ Processed mesh 303
#
# ✅ Processed mesh 304
#
# ✅ Processed mesh 305
#
# ✅ Processed mesh 306
#
# ✅ Processed mesh 307
#
# ✅ Processed mesh 308
#
# ✅ Processed mesh 309
#
# ✅ Processed mesh 310
#
# ✅ Processed mesh 311
#
# ✅ Processed mesh 312
#
# ✅ Processed mesh 313
#
# ✅ Processed mesh 314
#
# ✅ Processed mesh 315
#
# ✅ Processed mesh 316
#
# ✅ Processed mesh 317
#
# ✅ Processed mesh 318
#
# ✅ Processed mesh 319
#
# ✅ Processed mesh 320
#
# ✅ Processed mesh 321
#
# ✅ Processed mesh 322
#
# ✅ Processed mesh 323
#
# ✅ Processed mesh 324
#
# ✅ Processed mesh 325
#
# ✅ Processed mesh 326
#
# ✅ Processed mesh 327
#
# ✅ Processed mesh 328
#
# ✅ Processed mesh 329
#
# ✅ Processed mesh 330
#
# ✅ Processed mesh 331
#
# ✅ Processed mesh 332
#
# ✅ Processed mesh 333
#
# ✅ Processed mesh 334
#
# ✅ Processed mesh 335
#
# ✅ Processed mesh 336
#
# ✅ Processed mesh 337
#
# ✅ Processed mesh 338
#
# ✅ Processed mesh 339
#
# ✅ Processed mesh 340
#
# ✅ Processed mesh 341
#
# ✅ Processed mesh 342
#
# ✅ Processed mesh 343
#
# ✅ Processed mesh 344
#
# ✅ Processed mesh 345
#
# ✅ Processed mesh 346
#
# ✅ Processed mesh 347
#
# ✅ Processed mesh 348
#
# ✅ Processed mesh 349
#
# ✅ Processed mesh 350
#
# ✅ Processed mesh 351
#
# ✅ Processed mesh 352
#
# ✅ Processed mesh 353
#
# ✅ Processed mesh 354
#
# ✅ Processed mesh 355
#
# ✅ Processed mesh 356
#
# ✅ Processed mesh 357
#
# ✅ Processed mesh 358
#
# ✅ Processed mesh 359
#
# ✅ Processed mesh 360
#
# ✅ Processed mesh 361
#
# ✅ Processed mesh 362
#
# ✅ Processed mesh 363
#
# ✅ Processed mesh 364
#
# ✅ Processed mesh 365
#
# ✅ Processed mesh 366
#
# ✅ Processed mesh 367
#
# ✅ Processed mesh 368
#
# ✅ Processed mesh 369
#
# ✅ Processed mesh 370
#
# ✅ Processed mesh 371
#
# ✅ Processed mesh 372
#
# ✅ Processed mesh 373
#
# ✅ Processed mesh 374
#
# ✅ Processed mesh 375
#
# ✅ Processed mesh 376
#
# ✅ Processed mesh 377
#
# ✅ Processed mesh 378
#
# ✅ Processed mesh 379
#
# ✅ Processed mesh 380
#
# ✅ Processed mesh 381
#
# ✅ Processed mesh 382
#
# ✅ Processed mesh 383
#
# ✅ Processed mesh 384
#
# ✅ Processed mesh 385
#
# ✅ Processed mesh 386
#
# ✅ Processed mesh 387
#
# ✅ Processed mesh 388
#
# ✅ Processed mesh 389
#
# ✅ Processed mesh 390
#
# ✅ Processed mesh 391
#
# ✅ Processed mesh 392
#
# ✅ Processed mesh 393
#
# ✅ Processed mesh 394
#
# ✅ Processed mesh 395
#
# ✅ Processed mesh 396
#
# ✅ Processed mesh 397
#
# ✅ Processed mesh 398
#
# ✅ Processed mesh 399
#
# ✅ Processed mesh 400
#
# ✅ Processed mesh 401
#
# ✅ Processed mesh 402
#
# ✅ Processed mesh 403
#
# ✅ Processed mesh 404
#
# ✅ Processed mesh 405
#
# ✅ Processed mesh 406
#
# ✅ Processed mesh 407
#
# ✅ Processed mesh 408
#
# ✅ Processed mesh 409
#
# ✅ Processed mesh 410
#
# ✅ Processed mesh 411
#
# ✅ Processed mesh 412
#
# ✅ Processed mesh 413
#
# ✅ Processed mesh 414
#
# ✅ Processed mesh 415
#
# ✅ Processed mesh 416
#
# ✅ Processed mesh 417
#
# ✅ Processed mesh 418
#
# ✅ Processed mesh 419
#
# ✅ Processed mesh 420
#
# ✅ Processed mesh 421
#
# ✅ Processed mesh 422
#
# ✅ Processed mesh 423
#
# ✅ Processed mesh 424
#
# ✅ Processed mesh 425
#
# ✅ Processed mesh 426
#
# ✅ Processed mesh 427
#
# ✅ Processed mesh 428
#
# ✅ Processed mesh 429
#
# ✅ Processed mesh 430
#
# ✅ Processed mesh 431
#
# ✅ Processed mesh 432
#
# ✅ Processed mesh 433
#
# ✅ Processed mesh 434
#
# ✅ Processed mesh 435
#
# ✅ Processed mesh 436
#
# ✅ Processed mesh 437
#
# ✅ Processed mesh 438
#
# ✅ Processed mesh 439
#
# ✅ Processed mesh 440
#
# ✅ Processed mesh 441
#
# ✅ Processed mesh 442
#
# ✅ Processed mesh 443
#
# ✅ Processed mesh 444
#
# ✅ Processed mesh 445
#
# ✅ Processed mesh 446
#
# ✅ Processed mesh 447
#
# ✅ Processed mesh 448
#
# ✅ Processed mesh 449
#
# ✅ Processed mesh 450
#
# ✅ Processed mesh 451
#
# ✅ Processed mesh 452
#
# ✅ Processed mesh 453
#
# ✅ Processed mesh 454
#
# ✅ Processed mesh 455
#
# ✅ Processed mesh 456
#
# ✅ Processed mesh 457
#
# ✅ Processed mesh 458
#
# ✅ Processed mesh 459
#
# ✅ Processed mesh 460
#
# ✅ Processed mesh 461
#
# ✅ Processed mesh 462
#
# ✅ Processed mesh 463
#
# ✅ Processed mesh 464
#
# ✅ Processed mesh 465
#
# ✅ Processed mesh 466
#
# ✅ Processed mesh 467
#
# ✅ Processed mesh 468
#
# ✅ Processed mesh 469
#
# ✅ Processed mesh 470
#
# ✅ Processed mesh 471
#
# ✅ Processed mesh 472
#
# ✅ Processed mesh 473
#
# ✅ Processed mesh 474
#
# ✅ Processed mesh 475
#
# ✅ Processed mesh 476
#
# ✅ Processed mesh 477
#
# ✅ Processed mesh 478
#
# ✅ Processed mesh 479
#
# ✅ Processed mesh 480
#
# ✅ Processed mesh 481
#
# ✅ Processed mesh 482
#
# ✅ Processed mesh 483
#
# ✅ Processed mesh 484
#
# ✅ Processed mesh 485
#
# ✅ Processed mesh 486
#
# ✅ Processed mesh 487
#
# ✅ Processed mesh 488
#
# ✅ Processed mesh 489
#
# ✅ Processed mesh 490
#
# ✅ Processed mesh 491
#
# ✅ Processed mesh 492
#
# ✅ Processed mesh 493
#
# ✅ Processed mesh 494
#
# ✅ Processed mesh 495
#
# ✅ Processed mesh 496
#
# ✅ Processed mesh 497
#
# ✅ Processed mesh 498
#
# ✅ Processed mesh 499
#
# ✅ Processed mesh 500
#
# ✅ Processed mesh 501
#
# ✅ Processed mesh 502
#
# ✅ Processed mesh 503
#
# ✅ Processed mesh 504
#
# ✅ Processed mesh 505
#
# ✅ Processed mesh 506
#
# ✅ Processed mesh 507
#
# ✅ Processed mesh 508
#
# ✅ Processed mesh 509
#
# ✅ Processed mesh 510
#
# ✅ Processed mesh 511
#
# ✅ Processed mesh 512
#
# ✅ Processed mesh 513
#
# ✅ Processed mesh 514
#
# ✅ Processed mesh 515
#
# ✅ Processed mesh 516
#
# ✅ Processed mesh 517
#
# ✅ Processed mesh 518
#
# ✅ Processed mesh 519
#
# ✅ Processed mesh 520
#
# ✅ Processed mesh 521
#
# ✅ Processed mesh 522
#
# ✅ Processed mesh 523
#
# ✅ Processed mesh 524
#
# ✅ Processed mesh 525
#
# ✅ Processed mesh 526
#
# ✅ Processed mesh 527
#
# ✅ Processed mesh 528
#
# ✅ Processed mesh 529
#
# ✅ Processed mesh 530
#
# ✅ Processed mesh 531
#
# ✅ Processed mesh 532
#
# ✅ Processed mesh 533
#
# ✅ Processed mesh 534
#
# ✅ Processed mesh 535
#
# ✅ Processed mesh 536
#
# ✅ Processed mesh 537
#
# ✅ Processed mesh 538
#
# ✅ Processed mesh 539
#
# ✅ Processed mesh 540
#
# ✅ Processed mesh 541
#
# ✅ Processed mesh 542
#
# ✅ Processed mesh 543
#
# ✅ Processed mesh 544
#
# ✅ Processed mesh 545
#
# ✅ Processed mesh 546
#
# ✅ Processed mesh 547
#
# ✅ Processed mesh 548
#
# ✅ Processed mesh 549
#
# ✅ Processed mesh 550
#
# ✅ Processed mesh 551
#
# ✅ Processed mesh 552
#
# ✅ Processed mesh 553
#
# ✅ Processed mesh 554
#
# ✅ Processed mesh 555
#
# ✅ Processed mesh 556
#
# ✅ Processed mesh 557
#
# ✅ Processed mesh 558
#
# ✅ Processed mesh 559
#
# ✅ Processed mesh 560
#
# ✅ Processed mesh 561
#
# ✅ Processed mesh 562
#
# ✅ Processed mesh 563
#
# ✅ Processed mesh 564
#
# ✅ Processed mesh 565
#
# ✅ Processed mesh 566
#
# ✅ Processed mesh 567
#
# ✅ Processed mesh 568
#
# ✅ Processed mesh 569
#
# ✅ Processed mesh 570
#
# ✅ Processed mesh 571
#
# ✅ Processed mesh 572
#
# ✅ Processed mesh 573
#
# ✅ Processed mesh 574
#
# ✅ Processed mesh 575
#
# ✅ Processed mesh 576
#
# ✅ Processed mesh 577
#
# ✅ Processed mesh 578
#
# ✅ Processed mesh 579
#
# ✅ Processed mesh 580
#
# ✅ Processed mesh 581
#
# ✅ Processed mesh 582
#
# ✅ Processed mesh 583
#
# ✅ Processed mesh 584
#
# ✅ Processed mesh 585
#
# ✅ Processed mesh 586
#
# ✅ Processed mesh 587
#
# ✅ Processed mesh 588
#
# ✅ Processed mesh 589
#
# ✅ Processed mesh 590
#
# ✅ Processed mesh 591
#
# ✅ Processed mesh 592
#
# ✅ Processed mesh 593
#
# ✅ Processed mesh 594
#
# ✅ Processed mesh 595
#
# ✅ Processed mesh 596
#
# ✅ Processed mesh 597
#
# ✅ Processed mesh 598
#
# ✅ Processed mesh 599
#
# ✅ Processed mesh 600
#
# ✅ Processed mesh 601
#
# ✅ Processed mesh 602
#
# ✅ Processed mesh 603
#
# ✅ Processed mesh 604
#
# ✅ Processed mesh 605
#
# ✅ Processed mesh 606
#
# ✅ Processed mesh 607
#
# ✅ Processed mesh 608
#
# ✅ Processed mesh 609
#
# ✅ Processed mesh 610
#
# ✅ Processed mesh 611
#
# ✅ Processed mesh 612
#
# ✅ Processed mesh 613
#
# ✅ Processed mesh 614
#
# ✅ Processed mesh 615
#
# ✅ Processed mesh 616
#
# ✅ Processed mesh 617
#
# ✅ Processed mesh 618
#
# ✅ Processed mesh 619
#
# ✅ Processed mesh 620
#
# ✅ Processed mesh 621
#
# ✅ Processed mesh 622
#
# ✅ Processed mesh 623
#
# ✅ Processed mesh 624
#
# ✅ Processed mesh 625
#
# ✅ Processed mesh 626
#
# ✅ Processed mesh 627
#
# ✅ Processed mesh 628
#
# ✅ Processed mesh 629
#
# ✅ Processed mesh 630
#
# ✅ Processed mesh 631
#
# ✅ Processed mesh 632
#
# ✅ Processed mesh 633
#
# ✅ Processed mesh 634
#
# ✅ Processed mesh 635
#
# ✅ Processed mesh 636
#
# ✅ Processed mesh 637
#
# ✅ Processed mesh 638
#
# ✅ Processed mesh 639
#
# ✅ Processed mesh 640
#
# ✅ Processed mesh 641
#
# ✅ Processed mesh 642
#
# ✅ Processed mesh 643
#
# ✅ Processed mesh 644
#
# ✅ Processed mesh 645
#
# ✅ Processed mesh 646
#
# ✅ Processed mesh 647
#
# ✅ Processed mesh 648
#
# ✅ Processed mesh 649
#
# ✅ Processed mesh 650
#
# ✅ Processed mesh 651
#
# ✅ Processed mesh 652
#
# ✅ Processed mesh 653
#
# ✅ Processed mesh 654
#
# ✅ Processed mesh 655
#
# ✅ Processed mesh 656
#
# ✅ Processed mesh 657
#
# ✅ Processed mesh 658
#
# ✅ Processed mesh 659
#
# ✅ Processed mesh 660
#
# ✅ Processed mesh 661
#
# ✅ Processed mesh 662
#
# ✅ Processed mesh 663
#
# ✅ Processed mesh 664
#
# ✅ Processed mesh 665
#
# ✅ Processed mesh 666
#
# ✅ Processed mesh 667
#
# ✅ Processed mesh 668
#
# ✅ Processed mesh 669
#
# ✅ Processed mesh 670
#
# ✅ Processed mesh 671
#
# ✅ Processed mesh 672
#
# ✅ Processed mesh 673
#
# ✅ Processed mesh 674
#
# ✅ Processed mesh 675
#
# ✅ Processed mesh 676
#
# ✅ Processed mesh 677
#
# ✅ Processed mesh 678
#
# ✅ Processed mesh 679
#
# ✅ Processed mesh 680
#
# ✅ Processed mesh 681
#
# ✅ Processed mesh 682
#
# ✅ Processed mesh 683
#
# ✅ Processed mesh 684
#
# ✅ Processed mesh 685
#
# ✅ Processed mesh 686
#
# ✅ Processed mesh 687
#
# ✅ Processed mesh 688
#
# ✅ Processed mesh 689
#
# ✅ Processed mesh 690
#
# ✅ Processed mesh 691
#
# ✅ Processed mesh 692
#
# ✅ Processed mesh 693
#
# ✅ Processed mesh 694
#
# ✅ Processed mesh 695
#
# ✅ Processed mesh 696
#
# ✅ Processed mesh 697
#
# ✅ Processed mesh 698
#
# ✅ Processed mesh 699
#
# ✅ Processed mesh 700
#
# ✅ Processed mesh 701
#
# ✅ Processed mesh 702
#
# ✅ Processed mesh 703
#
# ✅ Processed mesh 704
#
# ✅ Processed mesh 705
#
# ✅ Processed mesh 706
#
# ✅ Processed mesh 707
#
# ✅ Processed mesh 708
#
# ✅ Processed mesh 709
#
# ✅ Processed mesh 710
#
# ✅ Processed mesh 711
#
# ✅ Processed mesh 712
#
# ✅ Processed mesh 713
#
# ✅ Processed mesh 714
#
# ✅ Processed mesh 715
#
# ✅ Processed mesh 716
#
# ✅ Processed mesh 717
#
# ✅ Processed mesh 718
#
# ✅ Processed mesh 719
#
# ✅ Processed mesh 720
#
# ✅ Processed mesh 721
#
# ✅ Processed mesh 722
#
# ✅ Processed mesh 723
#
# ✅ Processed mesh 724
#
# ✅ Processed mesh 725
#
# ✅ Processed mesh 726
#
# ✅ Processed mesh 727
#
# ✅ Processed mesh 728
#
# ✅ Processed mesh 729
#
# ✅ Processed mesh 730
#
# ✅ Processed mesh 731
#
# ✅ Processed mesh 732
#
# ✅ Processed mesh 733
#
# ✅ Processed mesh 734
#
# ✅ Processed mesh 735
#
# ✅ Processed mesh 736
#
# ✅ Processed mesh 737
#
# ✅ Processed mesh 738
#
# ✅ Processed mesh 739
#
# ✅ Processed mesh 740
#
# ✅ Processed mesh 741
#
# ✅ Processed mesh 742
#
# ✅ Processed mesh 743
#
# ✅ Processed mesh 744
#
# ✅ Processed mesh 745
#
# ✅ Processed mesh 746
#
# ✅ Processed mesh 747
#
# ✅ Processed mesh 748
#
# ✅ Processed mesh 749
#
# ✅ Processed mesh 750
#
# ✅ Processed mesh 751
#
# ✅ Processed mesh 752
#
# ✅ Processed mesh 753
#
# ✅ Processed mesh 754
#
# ✅ Processed mesh 755
#
# ✅ Processed mesh 756
#
# ✅ Processed mesh 757
#
# ✅ Processed mesh 758
#
# ✅ Processed mesh 759
#
# ✅ Processed mesh 760
#
# ✅ Processed mesh 761
#
# ✅ Processed mesh 762
#
# ✅ Processed mesh 763
#
# ✅ Processed mesh 764
#
# ✅ Processed mesh 765
#
# ✅ Processed mesh 766
#
# ✅ Processed mesh 767
#
# ✅ Processed mesh 768
#
# ✅ Processed mesh 769
#
# ✅ Processed mesh 770
#
# ✅ Processed mesh 771
#
# ✅ Processed mesh 772
#
# ✅ Processed mesh 773
#
# ✅ Processed mesh 774
#
# ✅ Processed mesh 775
#
# ✅ Processed mesh 776
#
# ✅ Processed mesh 777
#
# ✅ Processed mesh 778
#
# ✅ Processed mesh 779
#
# ✅ Processed mesh 780
#
# ✅ Processed mesh 781
#
# ✅ Processed mesh 782
#
# ✅ Processed mesh 783
#
# ✅ Processed mesh 784
#
# ✅ Processed mesh 785
#
# ✅ Processed mesh 786
#
# ✅ Processed mesh 787
#
# ✅ Processed mesh 788
#
# ✅ Processed mesh 789
#
# ✅ Processed mesh 790
#
# ✅ Processed mesh 791
#
# ✅ Processed mesh 792
#
# ✅ Processed mesh 793
#
# ✅ Processed mesh 794
#
# ✅ Processed mesh 795
#
# ✅ Processed mesh 796
#
# ✅ Processed mesh 797
#
# ✅ Processed mesh 798
#
# ✅ Processed mesh 799
#
# ✅ Processed mesh 800
#
# ✅ Processed mesh 801
#
# ✅ Processed mesh 802
#
# ✅ Processed mesh 803
#
# ✅ Processed mesh 804
#
# ✅ Processed mesh 805
#
# ✅ Processed mesh 806
#
# ✅ Processed mesh 807
#
# ✅ Processed mesh 808
#
# ✅ Processed mesh 809
#
# ✅ Processed mesh 810
#
# ✅ Processed mesh 811
#
# ✅ Processed mesh 812
#
# ✅ Processed mesh 813
#
# ✅ Processed mesh 814
#
# ✅ Processed mesh 815
#
# ✅ Processed mesh 816
#
# ✅ Processed mesh 817
#
# ✅ Processed mesh 818
#
# ✅ Processed mesh 819
#
# ✅ Processed mesh 820
#
# ✅ Processed mesh 821
#
# ✅ Processed mesh 822
#
# ✅ Processed mesh 823
#
# ✅ Processed mesh 824
#
# ✅ Processed mesh 825
#
# ✅ Processed mesh 826
#
# ✅ Processed mesh 827
#
# ✅ Processed mesh 828
#
# ✅ Processed mesh 829
#
# ✅ Processed mesh 830
#
# ✅ Processed mesh 831
#
# ✅ Processed mesh 832
#
# ✅ Processed mesh 833
#
# ✅ Processed mesh 834
#
# ✅ Processed mesh 835
#
# ✅ Processed mesh 836
#
# ✅ Processed mesh 837
#
# ✅ Processed mesh 838
#
# ✅ Processed mesh 839
#
# ✅ Processed mesh 840
#
# ✅ Processed mesh 841
#
# ✅ Processed mesh 842
#
# ✅ Processed mesh 843
#
# ✅ Processed mesh 844
#
# ✅ Processed mesh 845
#
# ✅ Processed mesh 846
#
# ✅ Processed mesh 847
#
# ✅ Processed mesh 848
#
# ✅ Processed mesh 849
#
# ✅ Processed mesh 850
#
# ✅ Processed mesh 851
#
# ✅ Processed mesh 852
#
# ✅ Processed mesh 853
#
# ✅ Processed mesh 854
#
# ✅ Processed mesh 855
#
# ✅ Processed mesh 856
#
# ✅ Processed mesh 857
#
# ✅ Processed mesh 858
#
# ✅ Processed mesh 859
#
# ✅ Processed mesh 860
#
# ✅ Processed mesh 861
#
# ✅ Processed mesh 862
#
# ✅ Processed mesh 863
#
# ✅ Processed mesh 864
#
# ✅ Processed mesh 865
#
# ✅ Processed mesh 866
#
# ✅ Processed mesh 867
#
# ✅ Processed mesh 868
#
# ✅ Processed mesh 869
#
# ✅ Processed mesh 870
#
# ✅ Processed mesh 871
#
# ✅ Processed mesh 872
#
# ✅ Processed mesh 873
#
# ✅ Processed mesh 874
#
# ✅ Processed mesh 875
#
# ✅ Processed mesh 876
#
# ✅ Processed mesh 877
#
# ✅ Processed mesh 878
#
# ✅ Processed mesh 879
#
# ✅ Processed mesh 880
#
# ✅ Processed mesh 881
#
# ✅ Processed mesh 882
#
# ✅ Processed mesh 883
#
# ✅ Processed mesh 884
#
# ✅ Processed mesh 885
#
# ✅ Processed mesh 886
#
# ✅ Processed mesh 887
#
# ✅ Processed mesh 888
#
# ✅ Processed mesh 889
#
# ✅ Processed mesh 890
#
# ✅ Processed mesh 891
#
# ✅ Processed mesh 892
#
# ✅ Processed mesh 893
#
# ✅ Processed mesh 894
#
# ✅ Processed mesh 895
#
# ✅ Processed mesh 896
#
# ✅ Processed mesh 897
#
# ✅ Processed mesh 898
#
# ✅ Processed mesh 899
#
# ✅ Processed mesh 900
#
# ✅ Processed mesh 901
#
# ✅ Processed mesh 902
#
# ✅ Processed mesh 903
#
# ✅ Processed mesh 904
#
# ✅ Processed mesh 905
#
# ✅ Processed mesh 906
#
# ✅ Processed mesh 907
#
# ✅ Processed mesh 908
#
# ✅ Processed mesh 909
#
# ✅ Processed mesh 910
#
# ✅ Processed mesh 911
#
# ✅ Processed mesh 912
#
# ✅ Processed mesh 913
#
# ✅ Processed mesh 914
#
# ✅ Processed mesh 915
#
# ✅ Processed mesh 916
#
# ✅ Processed mesh 917
#
# ✅ Processed mesh 918
#
# ✅ Processed mesh 919
#
# ✅ Processed mesh 920
#
# ✅ Processed mesh 921
#
# ✅ Processed mesh 922
#
# ✅ Processed mesh 923
#
# ✅ Processed mesh 924
#
# ✅ Processed mesh 925
#
# ✅ Processed mesh 926
#
# ✅ Processed mesh 927
#
# ✅ Processed mesh 928
#
# ✅ Processed mesh 929
#
# ✅ Processed mesh 930
#
# ✅ Processed mesh 931
#
# ✅ Processed mesh 932
#
# ✅ Processed mesh 933
#
# ✅ Processed mesh 934
#
# ✅ Processed mesh 935
#
# ✅ Processed mesh 936
#
# ✅ Processed mesh 937
#
# ✅ Processed mesh 938
#
# ✅ Processed mesh 939
#
# ✅ Processed mesh 940
#
# ✅ Processed mesh 941
#
# ✅ Processed mesh 942
#
# ✅ Processed mesh 943
#
# ✅ Processed mesh 944
#
# ✅ Processed mesh 945
#
# ✅ Processed mesh 946
#
# ✅ Processed mesh 947
#
# ✅ Processed mesh 948
#
# ✅ Processed mesh 949
#
# ✅ Processed mesh 950
#
# ✅ Processed mesh 951
#
# ✅ Processed mesh 952
#
# ✅ Processed mesh 953
#
# ✅ Processed mesh 954
#
# ✅ Processed mesh 955
#
# ✅ Processed mesh 956
#
# ✅ Processed mesh 957
#
# ✅ Processed mesh 958
#
# ✅ Processed mesh 959
#
# ✅ Processed mesh 960
#
# ✅ Processed mesh 961
#
# ✅ Processed mesh 962
#
# ✅ Processed mesh 963
#
# ✅ Processed mesh 964
#
# ✅ Processed mesh 965
#
# ✅ Processed mesh 966
#
# ✅ Processed mesh 967
#
# ✅ Processed mesh 968
#
# ✅ Processed mesh 969
#
# ✅ Processed mesh 970
#
# ✅ Processed mesh 971
#
# ✅ Processed mesh 972
#
# ✅ Processed mesh 973
#
# ✅ Processed mesh 974
#
# ✅ Processed mesh 975
#
# ✅ Processed mesh 976
#
# ✅ Processed mesh 977
#
# ✅ Processed mesh 978
#
# ✅ Processed mesh 979
#
# ✅ Processed mesh 980
#
# ✅ Processed mesh 981
#
# ✅ Processed mesh 982
#
# ✅ Processed mesh 983
#
# ✅ Processed mesh 984
#
# ✅ Processed mesh 985
#
# ✅ Processed mesh 986
#
# ✅ Processed mesh 987
#
# ✅ Processed mesh 988
#
# ✅ Processed mesh 989
#
# ✅ Processed mesh 990
#
# ✅ Processed mesh 991
#
# ✅ Processed mesh 992
#
# ✅ Processed mesh 993
#
# ✅ Processed mesh 994
#
# ✅ Processed mesh 995
#
# ✅ Processed mesh 996
#
# ✅ Processed mesh 997
#
# ✅ Processed mesh 998
#
# ✅ Processed mesh 999
#
# ✅ Processed mesh 1000
#
# ✅ Processed mesh 1001
#
# ✅ Processed mesh 1002
#
# ✅ Processed mesh 1003
#
# ✅ Processed mesh 1004
#
# ✅ Processed mesh 1005
#
# ✅ Processed mesh 1006
#
# ✅ Processed mesh 1007
#
# ✅ Processed mesh 1008
#
# ✅ Processed mesh 1009
#
# ✅ Processed mesh 1010
#
# ✅ Processed mesh 1011
#
# ✅ Processed mesh 1012
#
# ✅ Processed mesh 1013
#
# ✅ Processed mesh 1014
#
# ✅ Processed mesh 1015
#
# ✅ Processed mesh 1016
#
# ✅ Processed mesh 1017
#
# ✅ Processed mesh 1018
#
# ✅ Processed mesh 1019
#
# ✅ Processed mesh 1020
#
# ✅ Processed mesh 1021
#
# ✅ Processed mesh 1022
#
# ✅ Processed mesh 1023
#
# ✅ Processed mesh 1024
#
# ✅ Processed mesh 1025
#
# ✅ Processed mesh 1026
#
# ✅ Processed mesh 1027
#
# ✅ Processed mesh 1028
#
# ✅ Processed mesh 1029
#
# ✅ Processed mesh 1030
#
# ✅ Processed mesh 1031
#
# ✅ Processed mesh 1032
#
# ✅ Processed mesh 1033
#
# ✅ Processed mesh 1034
#
# ✅ Processed mesh 1035
#
# ✅ Processed mesh 1036
#
# ✅ Processed mesh 1037
#
# ✅ Processed mesh 1038
#
# ✅ Processed mesh 1039
#
# ✅ Processed mesh 1040
#
# ✅ Processed mesh 1041
#
# ✅ Processed mesh 1042
#
# ✅ Processed mesh 1043
#
# ✅ Processed mesh 1044
#
# ✅ Processed mesh 1045
#
# ✅ Processed mesh 1046
#
# ✅ Processed mesh 1047
#
# ✅ Processed mesh 1048
#
# ✅ Processed mesh 1049
#
# ✅ Processed mesh 1050
#
# ✅ Processed mesh 1051
#
# ✅ Processed mesh 1052
#
# ✅ Processed mesh 1053
#
# ✅ Processed mesh 1054
#
# ✅ Processed mesh 1055
#
# ✅ Processed mesh 1056
#
# ✅ Processed mesh 1057
#
# ✅ Processed mesh 1058
#
# ✅ Processed mesh 1059
#
# ✅ Processed mesh 1060
#
# ✅ Processed mesh 1061
#
# ✅ Processed mesh 1062
#
# ✅ Processed mesh 1063
#
# ✅ Processed mesh 1064
#
# ✅ Processed mesh 1065
#
# ✅ Processed mesh 1066
#
# ✅ Processed mesh 1067
#
# ✅ Processed mesh 1068
#
# ✅ Processed mesh 1069
#
# ✅ Processed mesh 1070
#
# ✅ Processed mesh 1071
#
# ✅ Processed mesh 1072
#
# ✅ Processed mesh 1073
#
# ✅ Processed mesh 1074
#
# ✅ Processed mesh 1075
#
# ✅ Processed mesh 1076
#
# ✅ Processed mesh 1077
#
# ✅ Processed mesh 1078
#
# ✅ Processed mesh 1079
#
# ✅ Processed mesh 1080
#
# ✅ Processed mesh 1081
#
# ✅ Processed mesh 1082
#
# ✅ Processed mesh 1083
#
# ✅ Processed mesh 1084
#
# ✅ Processed mesh 1085
#
# ✅ Processed mesh 1086
#
# ✅ Processed mesh 1087
#
# ✅ Processed mesh 1088
#
# ✅ Processed mesh 1089
#
# ✅ Processed mesh 1090
#
# ✅ Processed mesh 1091
#
# ✅ Processed mesh 1092
#
# ✅ Processed mesh 1093
#
# ✅ Processed mesh 1094
#
# ✅ Processed mesh 1095
#
# ✅ Processed mesh 1096
#
# ✅ Processed mesh 1097
#
# ✅ Processed mesh 1098
#
# ✅ Processed mesh 1099
#
# ✅ Processed mesh 1100
#
# ✅ Processed mesh 1101
#
# ✅ Processed mesh 1102
#
# ✅ Processed mesh 1103
#
# ✅ Processed mesh 1104
#
# ✅ Processed mesh 1105
#
# ✅ Processed mesh 1106
#
# ✅ Processed mesh 1107
#
# ✅ Processed mesh 1108
#
# ✅ Processed mesh 1109
#
# ✅ Processed mesh 1110
#
# ✅ Processed mesh 1111
#
# ✅ Processed mesh 1112
#
# ✅ Processed mesh 1113
#
# ✅ Processed mesh 1114
#
# ✅ Processed mesh 1115
#
# ✅ Processed mesh 1116
#
# ✅ Processed mesh 1117
#
# ✅ Processed mesh 1118
#
# ✅ Processed mesh 1119
#
# ✅ Processed mesh 1120
#
# ✅ Processed mesh 1121
#
# ✅ Processed mesh 1122
#
# ✅ Processed mesh 1123
#
# ✅ Processed mesh 1124
#
# ✅ Processed mesh 1125
#
# ✅ Processed mesh 1126
#
# ✅ Processed mesh 1127
#
# ✅ Processed mesh 1128
#
# ✅ Processed mesh 1129
#
# ✅ Processed mesh 1130
#
# ✅ Processed mesh 1131
#
# ✅ Processed mesh 1132
#
# ✅ Processed mesh 1133
#
# ✅ Processed mesh 1134
#
# ✅ Processed mesh 1135
#
# ✅ Processed mesh 1136
#
# ✅ Processed mesh 1137
#
# ✅ Processed mesh 1138
#
# ✅ Processed mesh 1139
#
# ✅ Processed mesh 1140
#
# ✅ Processed mesh 1141
#
# ✅ Processed mesh 1142
#
# ✅ Processed mesh 1143
#
# ✅ Processed mesh 1144
#
# ✅ Processed mesh 1145
#
# ✅ Processed mesh 1146
#
# ✅ Processed mesh 1147
#
# ✅ Processed mesh 1148
#
# ✅ Processed mesh 1149
#
# ✅ Processed mesh 1150
#
# ✅ Processed mesh 1151
#
# ✅ Processed mesh 1152
#
# ✅ Processed mesh 1153
#
# ✅ Processed mesh 1154
#
# ✅ Processed mesh 1155
#
# ✅ Processed mesh 1156
#
# ✅ Processed mesh 1157
#
# ✅ Processed mesh 1158
#
# ✅ Processed mesh 1159
#
# ✅ Processed mesh 1160
#
# ✅ Processed mesh 1161
#
# ✅ Processed mesh 1162
#
# ✅ Processed mesh 1163
#
# ✅ Processed mesh 1164
#
# ✅ Processed mesh 1165
#
# ✅ Processed mesh 1166
#
# ✅ Processed mesh 1167
#
# ✅ Processed mesh 1168
#
# ✅ Processed mesh 1169
#
# ✅ Processed mesh 1170
#
# ✅ Processed mesh 1171
#
# ✅ Processed mesh 1172
#
# ✅ Processed mesh 1173
#
# ✅ Processed mesh 1174
#
# ✅ Processed mesh 1175
#
# ✅ Processed mesh 1176
#
# ✅ Processed mesh 1177
#
# ✅ Processed mesh 1178
#
# ✅ Processed mesh 1179
#
# ✅ Processed mesh 1180
#
# ✅ Processed mesh 1181
#
# ✅ Processed mesh 1182
#
# ✅ Processed mesh 1183
#
# ✅ Processed mesh 1184
#
# ✅ Processed mesh 1185
#
# ✅ Processed mesh 1186
#
# ✅ Processed mesh 1187
#
# ✅ Processed mesh 1188
#
# ✅ Processed mesh 1189
#
# ✅ Processed mesh 1190
#
# ✅ Processed mesh 1191
#
# ✅ Processed mesh 1192
#
# ✅ Processed mesh 1193
#
# ✅ Processed mesh 1194
#
# ✅ Processed mesh 1195
#
# ✅ Processed mesh 1196
#
# ✅ Processed mesh 1197
#
# ✅ Processed mesh 1198
#
# ✅ Processed mesh 1199
#
# ✅ Processed mesh 1200
#
# ✅ Processed mesh 1201
#
# ✅ Processed mesh 1202
#
# ✅ Processed mesh 1203
#
# ✅ Processed mesh 1204
#
# ✅ Processed mesh 1205
#
# ✅ Processed mesh 1206
#
# ✅ Processed mesh 1207
#
# ✅ Processed mesh 1208
#
# ✅ Processed mesh 1209
#
# ✅ Processed mesh 1210
#
# ✅ Processed mesh 1211
#
# ✅ Processed mesh 1212
#
# ✅ Processed mesh 1213
#
# ✅ Processed mesh 1214
#
# ✅ Processed mesh 1215
#
# ✅ Processed mesh 1216
#
# ✅ Processed mesh 1217
#
# ✅ Processed mesh 1218
#
# ✅ Processed mesh 1219
#
# ✅ Processed mesh 1220
#
# ✅ Processed mesh 1221
#
# ✅ Processed mesh 1222
#
# ✅ Processed mesh 1223
#
# ✅ Processed mesh 1224
#
# ✅ Processed mesh 1225
#
# ✅ Processed mesh 1226
#
# ✅ Processed mesh 1227
#
# ✅ Processed mesh 1228
#
# ✅ Processed mesh 1229
#
# ✅ Processed mesh 1230
#
# ✅ Processed mesh 1231
#
# ✅ Processed mesh 1232
#
# ✅ Processed mesh 1233
#
# ✅ Processed mesh 1234
#
# ✅ Processed mesh 1235
#
# ✅ Processed mesh 1236
#
# ✅ Processed mesh 1237
#
# ✅ Processed mesh 1238
#
# ✅ Processed mesh 1239
#
# ✅ Processed mesh 1240
#
# ✅ Processed mesh 1241
#
# ✅ Processed mesh 1242
#
# ✅ Processed mesh 1243
#
# ✅ Processed mesh 1244
#
# ✅ Processed mesh 1245
#
# ✅ Processed mesh 1246
#
# ✅ Processed mesh 1247
#
# ✅ Processed mesh 1248
#
# ✅ Processed mesh 1249
#
# ✅ Processed mesh 1250
#
# ✅ Processed mesh 1251
#
# ✅ Processed mesh 1252
#
# ✅ Processed mesh 1253
#
# ✅ Processed mesh 1254
#
# ✅ Processed mesh 1255
#
# ✅ Processed mesh 1256
#
# ✅ Processed mesh 1257
#
# ✅ Processed mesh 1258
#
# ✅ Processed mesh 1259
#
# ✅ Processed mesh 1260
#
# ✅ Processed mesh 1261
#
# ✅ Processed mesh 1262
#
# ✅ Processed mesh 1263
#
# ✅ Processed mesh 1264
#
# ✅ Processed mesh 1265
#
# ✅ Processed mesh 1266
#
# ✅ Processed mesh 1267
#
# ✅ Processed mesh 1268
#
# ✅ Processed mesh 1269
#
# ✅ Processed mesh 1270
#
# ✅ Processed mesh 1271
#
# ✅ Processed mesh 1272
#
# ✅ Processed mesh 1273
#
# ✅ Processed mesh 1274
#
# ✅ Processed mesh 1275
#
# ✅ Processed mesh 1276
#
# ✅ Processed mesh 1277
#
# ✅ Processed mesh 1278
#
# ✅ Processed mesh 1279
#
# ✅ Processed mesh 1280
#
# ✅ Processed mesh 1281
#
# ✅ Processed mesh 1282
#
# ✅ Processed mesh 1283
#
# ✅ Processed mesh 1284
#
# ✅ Processed mesh 1285
#
# ✅ Processed mesh 1286
#
# ✅ Processed mesh 1287
#
# ✅ Processed mesh 1288
#
# ✅ Processed mesh 1289
#
# ✅ Processed mesh 1290
#
# ✅ Processed mesh 1291
#
# ✅ Processed mesh 1292
#
# ✅ Processed mesh 1293
#
# ✅ Processed mesh 1294
#
# ✅ Processed mesh 1295
#
# ✅ Processed mesh 1296
#
# ✅ Processed mesh 1297
#
# ✅ Processed mesh 1298
#
# ✅ Processed mesh 1299
#
# ✅ Processed mesh 1300
#
# ✅ Processed mesh 1301
#
# ✅ Processed mesh 1302
#
# ✅ Processed mesh 1303
#
# ✅ Processed mesh 1304
#
# ✅ Processed mesh 1305
#
# ✅ Processed mesh 1306
#
# ✅ Processed mesh 1307
#
# ✅ Processed mesh 1308
#
# ✅ Processed mesh 1309
#
# ✅ Processed mesh 1310
#
# ✅ Processed mesh 1311
#
# ✅ Processed mesh 1312
#
# ✅ Processed mesh 1313
#
# ✅ Processed mesh 1314
#
# ✅ Processed mesh 1315
#
# ✅ Processed mesh 1316
#
# ✅ Processed mesh 1317
#
# ✅ Processed mesh 1318
#
# ✅ Processed mesh 1319
#
# ✅ Processed mesh 1320
#
# ✅ Processed mesh 1321
#
# ✅ Processed mesh 1322
#
# ✅ Processed mesh 1323
#
# ✅ Processed mesh 1324
#
# ✅ Processed mesh 1325
#
# ✅ Processed mesh 1326
#
# ✅ Processed mesh 1327
#
# ✅ Processed mesh 1328
#
# ✅ Processed mesh 1329
#
# ✅ Processed mesh 1330
#
# ✅ Processed mesh 1331
#
# ✅ Processed mesh 1332
#
# ✅ Processed mesh 1333
#
# ✅ Processed mesh 1334
#
# ✅ Processed mesh 1335
#
# ✅ Processed mesh 1336
#
# ✅ Processed mesh 1337
#
# ✅ Processed mesh 1338
#
# ✅ Processed mesh 1339
#
# ✅ Processed mesh 1340
#
# ✅ Processed mesh 1341
#
# ✅ Processed mesh 1342
#
# ✅ Processed mesh 1343
#
# ✅ Processed mesh 1344
#
# ✅ Processed mesh 1345
#
# ✅ Processed mesh 1346
#
# ✅ Processed mesh 1347
#
# ✅ Processed mesh 1348
#
# ✅ Processed mesh 1349
#
# ✅ Processed mesh 1350
#
# ✅ Processed mesh 1351
#
# ✅ Processed mesh 1352
#
# ✅ Processed mesh 1353
#
# ✅ Processed mesh 1354
#
# ✅ Processed mesh 1355
#
# ✅ Processed mesh 1356
#
# ✅ Processed mesh 1357
#
# ✅ Processed mesh 1358
#
# ✅ Processed mesh 1359
#
# ✅ Processed mesh 1360
#
# ✅ Processed mesh 1361
#
# ✅ Processed mesh 1362
#
# ✅ Processed mesh 1363
#
# ✅ Processed mesh 1364
#
# ✅ Processed mesh 1365
#
# ✅ Processed mesh 1366
#
# ✅ Processed mesh 1367
#
# ✅ Processed mesh 1368
#
# ✅ Processed mesh 1369
#
# ✅ Processed mesh 1370
#
# ✅ Processed mesh 1371
#
# ✅ Processed mesh 1372
#
# ✅ Processed mesh 1373
#
# ✅ Processed mesh 1374
#
# ✅ Processed mesh 1375
#
# ✅ Processed mesh 1376
#
# ✅ Processed mesh 1377
#
# ✅ Processed mesh 1378
#
# ✅ Processed mesh 1379
#
# ✅ Processed mesh 1380
#
# ✅ Processed mesh 1381
#
# ✅ Processed mesh 1382
#
# ✅ Processed mesh 1383
#
# ✅ Processed mesh 1384
#
# ✅ Processed mesh 1385
#
# ✅ Processed mesh 1386
#
# ✅ Processed mesh 1387
#
# ✅ Processed mesh 1388
#
# ✅ Processed mesh 1389
#
# ✅ Processed mesh 1390
#
# ✅ Processed mesh 1391
#
# ✅ Processed mesh 1392
#
# ✅ Processed mesh 1393
#
# ✅ Processed mesh 1394
#
# ✅ Processed mesh 1395
#
# ✅ Processed mesh 1396
#
# ✅ Processed mesh 1397
#
# ✅ Processed mesh 1398
#
# ✅ Processed mesh 1399
#
# ✅ Processed mesh 1400
#
# ✅ Processed mesh 1401
#
# ✅ Processed mesh 1402
#
# ✅ Processed mesh 1403
#
# ✅ Processed mesh 1404
#
# ✅ Processed mesh 1405
#
# ✅ Processed mesh 1406
#
# ✅ Processed mesh 1407
#
# ✅ Processed mesh 1408
#
# ✅ Processed mesh 1409
#
# ✅ Processed mesh 1410
#
# ✅ Processed mesh 1411
#
# ✅ Processed mesh 1412
#
# ✅ Processed mesh 1413
#
# ✅ Processed mesh 1414
#
# ✅ Processed mesh 1415
#
# ✅ Processed mesh 1416
#
# ✅ Processed mesh 1417
#
# ✅ Processed mesh 1418
#
# ✅ Processed mesh 1419
#
# ✅ Processed mesh 1420
#
# ✅ Processed mesh 1421
#
# ✅ Processed mesh 1422
#
# ✅ Processed mesh 1423
#
# ✅ Processed mesh 1424
#
# ✅ Processed mesh 1425
#
# ✅ Processed mesh 1426
#
# ✅ Processed mesh 1427
#
# ✅ Processed mesh 1428
#
# ✅ Processed mesh 1429
#
# ✅ Processed mesh 1430
#
# ✅ Processed mesh 1431
#
# ✅ Processed mesh 1432
#
# ✅ Processed mesh 1433
#
# ✅ Processed mesh 1434
#
# ✅ Processed mesh 1435
#
# ✅ Processed mesh 1436
#
# ✅ Processed mesh 1437
#
# ✅ Processed mesh 1438
#
# ✅ Processed mesh 1439
#
# ✅ Processed mesh 1440
#
# ✅ Processed mesh 1441
#
# ✅ Processed mesh 1442
#
# ✅ Processed mesh 1443
#
# ✅ Processed mesh 1444
#
# ✅ Processed mesh 1445
#
# ✅ Processed mesh 1446
#
# ✅ Processed mesh 1447
#
# ✅ Processed mesh 1448
#
# ✅ Processed mesh 1449
#
# ✅ Processed mesh 1450
#
# ✅ Processed mesh 1451
#
# ✅ Processed mesh 1452
#
# ✅ Processed mesh 1453
#
# ✅ Processed mesh 1454
#
# ✅ Processed mesh 1455
#
# ✅ Processed mesh 1456
#
# ✅ Processed mesh 1457
#
# ✅ Processed mesh 1458
#
# ✅ Processed mesh 1459
#
# ✅ Processed mesh 1460
#
# ✅ Processed mesh 1461
#
# ✅ Processed mesh 1462
#
# ✅ Processed mesh 1463
#
# ✅ Processed mesh 1464
#
# ✅ Processed mesh 1465
#
# ✅ Processed mesh 1466
#
# ✅ Processed mesh 1467
#
# ✅ Processed mesh 1468
#
# ✅ Processed mesh 1469
#
# ✅ Processed mesh 1470
#
# ✅ Processed mesh 1471
#
# ✅ Processed mesh 1472
#
# ✅ Processed mesh 1473
#
# ✅ Processed mesh 1474
#
# ✅ Processed mesh 1475
#
# ✅ Processed mesh 1476
#
# ✅ Processed mesh 1477
#
# ✅ Processed mesh 1478
#
# ✅ Processed mesh 1479
#
# ✅ Processed mesh 1480
#
# ✅ Processed mesh 1481
#
# ✅ Processed mesh 1482
#
# ✅ Processed mesh 1483
#
# ✅ Processed mesh 1484
#
# ✅ Processed mesh 1485
#
# ✅ Processed mesh 1486
#
# ✅ Processed mesh 1487
#
# ✅ Processed mesh 1488
#
# ✅ Processed mesh 1489
#
# ✅ Processed mesh 1490
#
# ✅ Processed mesh 1491
#
# ✅ Processed mesh 1492
#
# ✅ Processed mesh 1493
#
# ✅ Processed mesh 1494
#
# ✅ Processed mesh 1495
#
# ✅ Processed mesh 1496
#
# ✅ Processed mesh 1497
#
# ✅ Processed mesh 1498
#
# ✅ Processed mesh 1499
#
# ✅ Processed mesh 1500
#
# ✅ Processed mesh 1501
#
# ✅ Processed mesh 1502
#
# ✅ Processed mesh 1503
#
# ✅ Processed mesh 1504
#
# ✅ Processed mesh 1505
#
# ✅ Processed mesh 1506
#
# ✅ Processed mesh 1507
#
# ✅ Processed mesh 1508
#
# ✅ Processed mesh 1509
#
# ✅ Processed mesh 1510
#
# ✅ Processed mesh 1511
#
# ✅ Processed mesh 1512
#
# ✅ Processed mesh 1513
#
# ✅ Processed mesh 1514
#
# ✅ Processed mesh 1515
#
# ✅ Processed mesh 1516
#
# ✅ Processed mesh 1517
#
# ✅ Processed mesh 1518
#
# ✅ Processed mesh 1519
#
# ✅ Processed mesh 1520
#
# ✅ Processed mesh 1521
#
# ✅ Processed mesh 1522
#
# ✅ Processed mesh 1523
#
# ✅ Processed mesh 1524
#
# ✅ Processed mesh 1525
#
# ✅ Processed mesh 1526
#
# ✅ Processed mesh 1527
#
# ✅ Processed mesh 1528
#
# ✅ Processed mesh 1529
#
# ✅ Processed mesh 1530
#
# ✅ Processed mesh 1531
#
# ✅ Processed mesh 1532
#
# ✅ Processed mesh 1533
#
# ✅ Processed mesh 1534
#
# ✅ Processed mesh 1535
#
# ✅ Processed mesh 1536
#
# ✅ Processed mesh 1537
#
# ✅ Processed mesh 1538
#
# ✅ Processed mesh 1539
#
# ✅ Processed mesh 1540
#
# ✅ Processed mesh 1541
#
# ✅ Processed mesh 1542
#
# ✅ Processed mesh 1543
#
# ✅ Processed mesh 1544
#
# ✅ Processed mesh 1545
#
# ✅ Processed mesh 1546
#
# ✅ Processed mesh 1547
#
# ✅ Processed mesh 1548
#
# ✅ Processed mesh 1549
#
# ✅ Processed mesh 1550
#
# ✅ Processed mesh 1551
#
# ✅ Processed mesh 1552
#
# ✅ Processed mesh 1553
#
# ✅ Processed mesh 1554
#
# ✅ Processed mesh 1555
#
# ✅ Processed mesh 1556
#
# ✅ Processed mesh 1557
#
# ✅ Processed mesh 1558
#
# ✅ Processed mesh 1559
#
# ✅ Processed mesh 1560
#
# ✅ Processed mesh 1561
#
# ✅ Processed mesh 1562
#
# ✅ Processed mesh 1563
#
# ✅ Processed mesh 1564
#
# ✅ Processed mesh 1565
#
# ✅ Processed mesh 1566
#
# ✅ Processed mesh 1567
#
# ✅ Processed mesh 1568
#
# ✅ Processed mesh 1569
#
# ✅ Processed mesh 1570
#
# ✅ Processed mesh 1571
#
# ✅ Processed mesh 1572
#
# ✅ Processed mesh 1573
#
# ✅ Processed mesh 1574
#
# ✅ Processed mesh 1575
#
# ✅ Processed mesh 1576
#
# ✅ Processed mesh 1577
#
# ✅ Processed mesh 1578
#
# ✅ Processed mesh 1579
#
# ✅ Processed mesh 1580
#
# ✅ Processed mesh 1581
#
# ✅ Processed mesh 1582
#
# ✅ Processed mesh 1583
#
# ✅ Processed mesh 1584
#
# ✅ Processed mesh 1585
#
# ✅ Processed mesh 1586
#
# ✅ Processed mesh 1587
#
# ✅ Processed mesh 1588
#
# ✅ Processed mesh 1589
#
# ✅ Processed mesh 1590
#
# ✅ Processed mesh 1591
#
# ✅ Processed mesh 1592
#
# ✅ Processed mesh 1593
#
# ✅ Processed mesh 1594
#
# ✅ Processed mesh 1595
#
# ✅ Processed mesh 1596
#
# ✅ Processed mesh 1597
#
# ✅ Processed mesh 1598
#
# ✅ Processed mesh 1599
#
# ✅ Processed mesh 1600
#
# ✅ Processed mesh 1601
#
# ✅ Processed mesh 1602
#
# ✅ Processed mesh 1603
#
# ✅ Processed mesh 1604
#
# ✅ Processed mesh 1605
#
# ✅ Processed mesh 1606
#
# ✅ Processed mesh 1607
#
# ✅ Processed mesh 1608
#
# ✅ Processed mesh 1609
#
# ✅ Processed mesh 1610
#
# ✅ Processed mesh 1611
#
# ✅ Processed mesh 1612
#
# ✅ Processed mesh 1613
#
# ✅ Processed mesh 1614
#
# ✅ Processed mesh 1615
#
# ✅ Processed mesh 1616
#
# ✅ Processed mesh 1617
#
# ✅ Processed mesh 1618
#
# ✅ Processed mesh 1619
#
# ✅ Processed mesh 1620
#
# ✅ Processed mesh 1621
#
# ✅ Processed mesh 1622
#
# ✅ Processed mesh 1623
#
# ✅ Processed mesh 1624
#
# ✅ Processed mesh 1625
#
# ✅ Processed mesh 1626
#
# ✅ Processed mesh 1627
#
# ✅ Processed mesh 1628
#
# ✅ Processed mesh 1629
#
# ✅ Processed mesh 1630
#
# ✅ Processed mesh 1631
#
# ✅ Processed mesh 1632
#
# ✅ Processed mesh 1633
#
# ✅ Processed mesh 1634
#
# ✅ Processed mesh 1635
#
# ✅ Processed mesh 1636
#
# ✅ Processed mesh 1637
#
# ✅ Processed mesh 1638
#
# ✅ Processed mesh 1639
#
# ✅ Processed mesh 1640
#
# ✅ Processed mesh 1641
#
# ✅ Processed mesh 1642
#
# ✅ Processed mesh 1643
#
# ✅ Processed mesh 1644
#
# ✅ Processed mesh 1645
#
# ✅ Processed mesh 1646
#
# ✅ Processed mesh 1647
#
# ✅ Processed mesh 1648
#
# ✅ Processed mesh 1649
#
# ✅ Processed mesh 1650
#
# ✅ Processed mesh 1651
#
# ✅ Processed mesh 1652
#
# ✅ Processed mesh 1653
#
# ✅ Processed mesh 1654
#
# ✅ Processed mesh 1655
#
# ✅ Processed mesh 1656
#
# ✅ Processed mesh 1657
#
# ✅ Processed mesh 1658
#
# ✅ Processed mesh 1659
#
# ✅ Processed mesh 1660
#
# ✅ Processed mesh 1661
#
# ✅ Processed mesh 1662
#
# ✅ Processed mesh 1663
#
# ✅ Processed mesh 1664
#
# ✅ Processed mesh 1665
#
# ✅ Processed mesh 1666
#
# ✅ Processed mesh 1667
#
# ✅ Processed mesh 1668
#
# ✅ Processed mesh 1669
#
# ✅ Processed mesh 1670
#
# ✅ Processed mesh 1671
#
# ✅ Processed mesh 1672
#
# ✅ Processed mesh 1673
#
# ✅ Processed mesh 1674
#
# ✅ Processed mesh 1675
#
# ✅ Processed mesh 1676
#
# ✅ Processed mesh 1677
#
# ✅ Processed mesh 1678
#
# ✅ Processed mesh 1679
#
# ✅ Processed mesh 1680
#
# ✅ Processed mesh 1681
#
# ✅ Processed mesh 1682
#
# ✅ Processed mesh 1683
#
# ✅ Processed mesh 1684
#
# ✅ Processed mesh 1685
#
# ✅ Processed mesh 1686
#
# ✅ Processed mesh 1687
#
# ✅ Processed mesh 1688
#
# ✅ Processed mesh 1689
#
# ✅ Processed mesh 1690
#
# ✅ Processed mesh 1691
#
# ✅ Processed mesh 1692
#
# ✅ Processed mesh 1693
#
# ✅ Processed mesh 1694
#
# ✅ Processed mesh 1695
#
# ✅ Processed mesh 1696
#
# ✅ Processed mesh 1697
#
# ✅ Processed mesh 1698
#
# ✅ Processed mesh 1699
#
# ✅ Processed mesh 1700
#
# ✅ Processed mesh 1701
#
# ✅ Processed mesh 1702
#
# ✅ Processed mesh 1703
#
# ✅ Processed mesh 1704
#
# ✅ Processed mesh 1705
#
# ✅ Processed mesh 1706
#
# ✅ Processed mesh 1707
#
# ✅ Processed mesh 1708
#
# ✅ Processed mesh 1709
#
# ✅ Processed mesh 1710
#
# ✅ Processed mesh 1711
#
# ✅ Processed mesh 1712
#
# ✅ Processed mesh 1713
#
# ✅ Processed mesh 1714
#
# ✅ Processed mesh 1715
#
# ✅ Processed mesh 1716
#
# ✅ Processed mesh 1717
#
# ✅ Processed mesh 1718
#
# ✅ Processed mesh 1719
#
# ✅ Processed mesh 1720
#
# ✅ Processed mesh 1721
#
# ✅ Processed mesh 1722
#
# ✅ Processed mesh 1723
#
# ✅ Processed mesh 1724
#
# ✅ Processed mesh 1725
#
# ✅ Processed mesh 1726
#
# ✅ Processed mesh 1727
#
# ✅ Processed mesh 1728
#
# ✅ Processed mesh 1729
#
# ✅ Processed mesh 1730
#
# ✅ Processed mesh 1731
#
# ✅ Processed mesh 1732
#
# ✅ Processed mesh 1733
#
# ✅ Processed mesh 1734
#
# ✅ Processed mesh 1735
#
# ✅ Processed mesh 1736
#
# ✅ Processed mesh 1737
#
# ✅ Processed mesh 1738
#
# ✅ Processed mesh 1739
#
# ✅ Processed mesh 1740
#
# ✅ Processed mesh 1741
#
# ✅ Processed mesh 1742
#
# ✅ Processed mesh 1743
#
# ✅ Processed mesh 1744
#
# ✅ Processed mesh 1745
#
# ✅ Processed mesh 1746
#
# ✅ Processed mesh 1747
#
# ✅ Processed mesh 1748
#
# ✅ Processed mesh 1749
#
# ✅ Processed mesh 1750
#
# ✅ Processed mesh 1751
#
# ✅ Processed mesh 1752
#
# ✅ Processed mesh 1753
#
# ✅ Processed mesh 1754
#
# ✅ Processed mesh 1755
#
# ✅ Processed mesh 1756
#
# ✅ Processed mesh 1757
#
# ✅ Processed mesh 1758
#
# ✅ Processed mesh 1759
#
# ✅ Processed mesh 1760
#
# ✅ Processed mesh 1761
#
# ✅ Processed mesh 1762
#
# ✅ Processed mesh 1763
#
# ✅ Processed mesh 1764
#
# ✅ Processed mesh 1765
#
# ✅ Processed mesh 1766
#
# ✅ Processed mesh 1767
#
# ✅ Processed mesh 1768
#
# ✅ Processed mesh 1769
#
# ✅ Processed mesh 1770
#
# ✅ Processed mesh 1771
#
# ✅ Processed mesh 1772
#
# ✅ Processed mesh 1773
#
# ✅ Processed mesh 1774
#
# ✅ Processed mesh 1775
#
# ✅ Processed mesh 1776
#
# ✅ Processed mesh 1777
#
# ✅ Processed mesh 1778
#
# ✅ Processed mesh 1779
#
# ✅ Processed mesh 1780
#
# ✅ Processed mesh 1781
#
# ✅ Processed mesh 1782
#
# ✅ Processed mesh 1783
#
# ✅ Processed mesh 1784
#
# ✅ Processed mesh 1785
#
# ✅ Processed mesh 1786
#
# ✅ Processed mesh 1787
#
# ✅ Processed mesh 1788
#
# ✅ Processed mesh 1789
#
# ✅ Processed mesh 1790
#
# ✅ Processed mesh 1791
#
# ✅ Processed mesh 1792
#
# ✅ Processed mesh 1793
#
# ✅ Processed mesh 1794
#
# ✅ Processed mesh 1795
#
# ✅ Processed mesh 1796
#
# ✅ Processed mesh 1797
#
# ✅ Processed mesh 1798
#
# ✅ Processed mesh 1799
#
# ✅ Processed mesh 1800
#
# ✅ Processed mesh 1801
#
# ✅ Processed mesh 1802
#
# ✅ Processed mesh 1803
#
# ✅ Processed mesh 1804
#
# ✅ Processed mesh 1805
#
# ✅ Processed mesh 1806
#
# ✅ Processed mesh 1807
#
# ✅ Processed mesh 1808
#
# ✅ Processed mesh 1809
#
# ✅ Processed mesh 1810
#
# ✅ Processed mesh 1811
#
# ✅ Processed mesh 1812
#
# ✅ Processed mesh 1813
#
# ✅ Processed mesh 1814
#
# ✅ Processed mesh 1815
#
# ✅ Processed mesh 1816
#
# ✅ Processed mesh 1817
#
# ✅ Processed mesh 1818
#
# ✅ Processed mesh 1819
#
# ✅ Processed mesh 1820
#
# ✅ Processed mesh 1821
#
# ✅ Processed mesh 1822
#
# ✅ Processed mesh 1823
#
# ✅ Processed mesh 1824
#
# ✅ Processed mesh 1825
#
# ✅ Processed mesh 1826
#
# ✅ Processed mesh 1827
#
# ✅ Processed mesh 1828
#
# ✅ Processed mesh 1829
#
# ✅ Processed mesh 1830
#
# ✅ Processed mesh 1831
#
# ✅ Processed mesh 1832
#
# ✅ Processed mesh 1833
#
# ✅ Processed mesh 1834
#
# ✅ Processed mesh 1835
#
# ✅ Processed mesh 1836
#
# ✅ Processed mesh 1837
#
# ✅ Processed mesh 1838
#
# ✅ Processed mesh 1839
#
# ✅ Processed mesh 1840
#
# ✅ Processed mesh 1841
#
# ✅ Processed mesh 1842
#
# ✅ Processed mesh 1843
#
# ✅ Processed mesh 1844
#
# ✅ Processed mesh 1845
#
# ✅ Processed mesh 1846
#
# ✅ Processed mesh 1847
#
# ✅ Processed mesh 1848
#
# ✅ Processed mesh 1849
#
# ✅ Processed mesh 1850
#
# ✅ Processed mesh 1851
#
# ✅ Processed mesh 1852
#
# ✅ Processed mesh 1853
#
# ✅ Processed mesh 1854
#
# ✅ Processed mesh 1855
#
# ✅ Processed mesh 1856
#
# ✅ Processed mesh 1857
#
# ✅ Processed mesh 1858
#
# ✅ Processed mesh 1859
#
# ✅ Processed mesh 1860
#
# ✅ Processed mesh 1861
#
# ✅ Processed mesh 1862
#
# ✅ Processed mesh 1863
#
# ✅ Processed mesh 1864
#
# ✅ Processed mesh 1865
#
# ✅ Processed mesh 1866
#
# ✅ Processed mesh 1867
#
# ✅ Processed mesh 1868
#
# ✅ Processed mesh 1869
#
# ✅ Processed mesh 1870
#
# ✅ Processed mesh 1871
#
# ✅ Processed mesh 1872
#
# ✅ Processed mesh 1873
#
# ✅ Processed mesh 1874
#
# ✅ Processed mesh 1875
#
# ✅ Processed mesh 1876
#
# ✅ Processed mesh 1877
#
# ✅ Processed mesh 1878
#
# ✅ Processed mesh 1879
#
# ✅ Processed mesh 1880
#
# ✅ Processed mesh 1881
#
# ✅ Processed mesh 1882
#
# ✅ Processed mesh 1883
#
# ✅ Processed mesh 1884
#
# ✅ Processed mesh 1885
#
# ✅ Processed mesh 1886
#
# ✅ Processed mesh 1887
#
# ✅ Processed mesh 1888
#
# ✅ Processed mesh 1889
#
# ✅ Processed mesh 1890
#
# ✅ Processed mesh 1891
#
# ✅ Processed mesh 1892
#
# ✅ Processed mesh 1893
#
# ✅ Processed mesh 1894
#
# ✅ Processed mesh 1895
#
# ✅ Processed mesh 1896
#
# ✅ Processed mesh 1897
#
# ✅ Processed mesh 1898
#
# ✅ Processed mesh 1899
#
# ✅ Processed mesh 1900
#
# ✅ Processed mesh 1901
#
# ✅ Processed mesh 1902
#
# ✅ Processed mesh 1903
#
# ✅ Processed mesh 1904
#
# ✅ Processed mesh 1905
#
# ✅ Processed mesh 1906
#
# ✅ Processed mesh 1907
#
# ✅ Processed mesh 1908
#
# ✅ Processed mesh 1909
#
# ✅ Processed mesh 1910
#
# ✅ Processed mesh 1911
#
# ✅ Processed mesh 1912
#
# ✅ Processed mesh 1913
#
# ✅ Processed mesh 1914
#
# ✅ Processed mesh 1915
#
# ✅ Processed mesh 1916
#
# ✅ Processed mesh 1917
#
# ✅ Processed mesh 1918
#
# ✅ Processed mesh 1919
#
# ✅ Processed mesh 1920
#
# ✅ Processed mesh 1921
#
# ✅ Processed mesh 1922
#
# ✅ Processed mesh 1923
#
# ✅ Processed mesh 1924
#
# ✅ Processed mesh 1925
#
# ✅ Processed mesh 1926
#
# ✅ Processed mesh 1927
#
# ✅ Processed mesh 1928
#
# ✅ Processed mesh 1929
#
# ✅ Processed mesh 1930
#
# ✅ Processed mesh 1931
#
# ✅ Processed mesh 1932
#
# ✅ Processed mesh 1933
#
# ✅ Processed mesh 1934
#
# ✅ Processed mesh 1935
#
# ✅ Processed mesh 1936
#
# ✅ Processed mesh 1937
#
# ✅ Processed mesh 1938
#
# ✅ Processed mesh 1939
#
# ✅ Processed mesh 1940
#
# ✅ Processed mesh 1941
#
# ✅ Processed mesh 1942
#
# ✅ Processed mesh 1943
#
# ✅ Processed mesh 1944
#
# ✅ Processed mesh 1945
#
# ✅ Processed mesh 1946
#
# ✅ Processed mesh 1947
#
# ✅ Processed mesh 1948
#
# ✅ Processed mesh 1949
#
# ✅ Processed mesh 1950
#
# ✅ Processed mesh 1951
#
# ✅ Processed mesh 1952
#
# ✅ Processed mesh 1953
#
# ✅ Processed mesh 1954
#
# ✅ Processed mesh 1955
#
# ✅ Processed mesh 1956
#
# ✅ Processed mesh 1957
#
# ✅ Processed mesh 1958
#
# ✅ Processed mesh 1959
#
# ✅ Processed mesh 1960
#
# ✅ Processed mesh 1961
#
# ✅ Processed mesh 1962
#
# ✅ Processed mesh 1963
#
# ✅ Processed mesh 1964
#
# ✅ Processed mesh 1965
#
# ✅ Processed mesh 1966
#
# ✅ Processed mesh 1967
#
# ✅ Processed mesh 1968
#
# ✅ Processed mesh 1969
#
# ✅ Processed mesh 1970
#
# ✅ Processed mesh 1971
#
# ✅ Processed mesh 1972
#
# ✅ Processed mesh 1973
#
# ✅ Processed mesh 1974
#
# ✅ Processed mesh 1975
#
# ✅ Processed mesh 1976
#
# ✅ Processed mesh 1977
#
# ✅ Processed mesh 1978
#
# ✅ Processed mesh 1979
#
# ✅ Processed mesh 1980
#
# ✅ Processed mesh 1981
#
# ✅ Processed mesh 1982
#
# ✅ Processed mesh 1983
#
# ✅ Processed mesh 1984
#
# ✅ Processed mesh 1985
#
# ✅ Processed mesh 1986
#
# ✅ Processed mesh 1987
#
# ✅ Processed mesh 1988
#
# ✅ Processed mesh 1989
#
# ✅ Processed mesh 1990
#
# ✅ Processed mesh 1991
#
# ✅ Processed mesh 1992
#
# ✅ Processed mesh 1993
#
# ✅ Processed mesh 1994
#
# ✅ Processed mesh 1995
#
# ✅ Processed mesh 1996
#
# ✅ Processed mesh 1997
#
# ✅ Processed mesh 1998
#
# ✅ Processed mesh 1999
#
# ✅ Processed mesh 2000
#
# ✅ Processed mesh 2001
#
# ✅ Processed mesh 2002
#
# ✅ Processed mesh 2003
#
# ✅ Processed mesh 2004
#
# ✅ Processed mesh 2005
#
# ✅ Processed mesh 2006
#
# ✅ Processed mesh 2007
#
# ✅ Processed mesh 2008
#
# ✅ Processed mesh 2009
#
# ✅ Processed mesh 2010
#
# ✅ Processed mesh 2011
#
# ✅ Processed mesh 2012
#
# ✅ Processed mesh 2013
#
# ✅ Processed mesh 2014
#
# ✅ Processed mesh 2015
#
# ✅ Processed mesh 2016
#
# ✅ Processed mesh 2017
#
# ✅ Processed mesh 2018
#
# ✅ Processed mesh 2019
#
# ✅ Processed mesh 2020
#
# ✅ Processed mesh 2021
#
# ✅ Processed mesh 2022
#
# ✅ Processed mesh 2023
#
# ✅ Processed mesh 2024
#
# ✅ Processed mesh 2025
#
# ✅ Processed mesh 2026
#
# ✅ Processed mesh 2027
#
# ✅ Processed mesh 2028
#
# ✅ Processed mesh 2029
#
# ✅ Processed mesh 2030
#
# ✅ Processed mesh 2031
#
# ✅ Processed mesh 2032
#
# ✅ Processed mesh 2033
#
# ✅ Processed mesh 2034
#
# ✅ Processed mesh 2035
#
# ✅ Processed mesh 2036
#
# ✅ Processed mesh 2037
#
# ✅ Processed mesh 2038
#
# ✅ Processed mesh 2039
#
# ✅ Processed mesh 2040
#
# ✅ Processed mesh 2041
#
# ✅ Processed mesh 2042
#
# ✅ Processed mesh 2043
#
# ✅ Processed mesh 2044
#
# ✅ Processed mesh 2045
#
# ✅ Processed mesh 2046
#
# ✅ Processed mesh 2047
#
# ✅ Processed mesh 2048
#
# ✅ Processed mesh 2049
#
# ✅ Processed mesh 2050
#
# ✅ Processed mesh 2051
#
# ✅ Processed mesh 2052
#
# ✅ Processed mesh 2053
#
# ✅ Processed mesh 2054
#
# ✅ Processed mesh 2055
#
# ✅ Processed mesh 2056
#
# ✅ Processed mesh 2057
#
# ✅ Processed mesh 2058
#
# ✅ Processed mesh 2059
#
# ✅ Processed mesh 2060
#
# ✅ Processed mesh 2061
#
# ✅ Processed mesh 2062
#
# ✅ Processed mesh 2063
#
# ✅ Processed mesh 2064
#
# ✅ Processed mesh 2065
#
# ✅ Processed mesh 2066
#
# ✅ Processed mesh 2067
#
# ✅ Processed mesh 2068
#
# ✅ Processed mesh 2069
#
# ✅ Processed mesh 2070
#
# ✅ Processed mesh 2071
#
# ✅ Processed mesh 2072
#
# ✅ Processed mesh 2073
#
# ✅ Processed mesh 2074
#
# ✅ Processed mesh 2075
#
# ✅ Processed mesh 2076
#
# ✅ Processed mesh 2077
#
# ✅ Processed mesh 2078
#
# ✅ Processed mesh 2079
#
# ✅ Processed mesh 2080
#
# ✅ Processed mesh 2081
#
# ✅ Processed mesh 2082
#
# ✅ Processed mesh 2083
#
# ✅ Processed mesh 2084
#
# ✅ Processed mesh 2085
#
# ✅ Processed mesh 2086
#
# ✅ Processed mesh 2087
#
# ✅ Processed mesh 2088
#
# ✅ Processed mesh 2089
#
# ✅ Processed mesh 2090
#
# ✅ Processed mesh 2091
#
# ✅ Processed mesh 2092
#
# ✅ Processed mesh 2093
#
# ✅ Processed mesh 2094
#
# ✅ Processed mesh 2095
#
# ✅ Processed mesh 2096
#
# ✅ Processed mesh 2097
#
# ✅ Processed mesh 2098
#
# ✅ Processed mesh 2099
#
# ✅ Processed mesh 2100
#
# ✅ Processed mesh 2101
#
# ✅ Processed mesh 2102
#
# ✅ Processed mesh 2103
#
# ✅ Processed mesh 2104
#
# ✅ Processed mesh 2105
#
# ✅ Processed mesh 2106
#
# ✅ Processed mesh 2107
#
# ✅ Processed mesh 2108
#
# ✅ Processed mesh 2109
#
# ✅ Processed mesh 2110
#
# ✅ Processed mesh 2111
#
# ✅ Processed mesh 2112
#
# ✅ Processed mesh 2113
#
# ✅ Processed mesh 2114
#
# ✅ Processed mesh 2115
#
# ✅ Processed mesh 2116
#
# ✅ Processed mesh 2117
#
# ✅ Processed mesh 2118
#
# ✅ Processed mesh 2119
#
# ✅ Processed mesh 2120
#
# ✅ Processed mesh 2121
#
# ✅ Processed mesh 2122
#
# ✅ Processed mesh 2123
#
# ✅ Processed mesh 2124
#
# ✅ Processed mesh 2125
#
# ✅ Processed mesh 2126
#
# ✅ Processed mesh 2127
#
# ✅ Processed mesh 2128
#
# ✅ Processed mesh 2129
#
# ✅ Processed mesh 2130
#
# ✅ Processed mesh 2131
#
# ✅ Processed mesh 2132
#
# ✅ Processed mesh 2133
#
# ✅ Processed mesh 2134
#
# ...
#
# ✅ Processed mesh 3309
#
# ✅ Processed mesh 3310
#
# ✅ Processed mesh 3311
#
# ✅ Processed mesh 3312
#
# ✅ Processed mesh 3313
#
# ✅ Processed mesh 3314
#
# ✅ Processed mesh 3315
#
# ✅ Processed mesh 3316
#
# ✅ Processed mesh 3317
#
# ✅ Processed mesh 3318
#
# ✅ Processed mesh 3319
#
# ✅ Processed mesh 3320
#
# ✅ Processed mesh 3321
#
# ✅ Processed mesh 3322
#
# ✅ Processed mesh 3323
#
# ✅ Processed mesh 3324
#
# ✅ Processed mesh 3325
#
# ✅ Processed mesh 3326
#
# ✅ Processed mesh 3327
#
# ✅ Processed mesh 3328
#
# ✅ Processed mesh 3329
#
# ✅ Processed mesh 3330
#
# ✅ Processed mesh 3331
#
# ✅ Processed mesh 3332
#
# ✅ Processed mesh 3333
#
# ✅ Processed mesh 3334
#
# ✅ Processed mesh 3335
#
# ✅ Processed mesh 3336
#
# ✅ Processed mesh 3337
#
# ✅ Processed mesh 3338
#
# ✅ Processed mesh 3339
#
# ✅ Processed mesh 3340
#
# ✅ Processed mesh 3341
#
# ✅ Processed mesh 3342
#
# ✅ Processed mesh 3343
#
# ✅ Processed mesh 3344
#
# ✅ Processed mesh 3345
#
# ✅ Processed mesh 3346
#
# ✅ Processed mesh 3347
#
# ✅ Processed mesh 3348
#
# ✅ Processed mesh 3349
#
# ✅ Processed mesh 3350
#
# ✅ Processed mesh 3351
#
# ✅ Processed mesh 3352
#
# ✅ Processed mesh 3353
#
# ✅ Processed mesh 3354
#
# ✅ Processed mesh 3355
#
# ✅ Processed mesh 3356
#
# ✅ Processed mesh 3357
#
# ✅ Processed mesh 3358
#
# ✅ Processed mesh 3359
#
# ✅ Processed mesh 3360
#
# ✅ Processed mesh 3361
#
# ✅ Processed mesh 3362
#
# ✅ Processed mesh 3363
#
# ✅ Processed mesh 3364
#
# ✅ Processed mesh 3365
#
# ✅ Processed mesh 3366
#
# ✅ Processed mesh 3367
#
# ✅ Processed mesh 3368
#
# ✅ Processed mesh 3369
#
# ✅ Processed mesh 3370
#
# ✅ Processed mesh 3371
#
# ✅ Processed mesh 3372
#
# ✅ Processed mesh 3373
#
# ✅ Processed mesh 3374
#
# ✅ Processed mesh 3375
#
# ✅ Processed mesh 3376
#
# ✅ Processed mesh 3377
#
# ✅ Processed mesh 3378
#
# ✅ Processed mesh 3379
#
# ✅ Processed mesh 3380
#
# ✅ Processed mesh 3381
#
# ✅ Processed mesh 3382
#
# ✅ Processed mesh 3383
#
# ✅ Processed mesh 3384
#
# ✅ Processed mesh 3385
#
# ✅ Processed mesh 3386
#
# ✅ Processed mesh 3387
#
# ✅ Processed mesh 3388
#
# ✅ Processed mesh 3389
#
# ✅ Processed mesh 3390
#
# ✅ Processed mesh 3391
#
# ✅ Processed mesh 3392
#
# ✅ Processed mesh 3393
#
# ✅ Processed mesh 3394
#
# ✅ Processed mesh 3395
#
# ✅ Processed mesh 3396
#
# ✅ Processed mesh 3397
#
# ✅ Processed mesh 3398
#
# ✅ Processed mesh 3399
#
# ✅ Processed mesh 3400
#
# ✅ Processed mesh 3401
#
# ✅ Processed mesh 3402
#
# ✅ Processed mesh 3403
#
# ✅ Processed mesh 3404
#
# ✅ Processed mesh 3405
#
# ✅ Processed mesh 3406
#
# ✅ Processed mesh 3407
#
# ✅ Processed mesh 3408
#
# ✅ Processed mesh 3409
#
# ✅ Processed mesh 3410
#
# ✅ Processed mesh 3411
#
# ✅ Processed mesh 3412
#
# ✅ Processed mesh 3413
#
# ✅ Processed mesh 3414
#
# ✅ Processed mesh 3415
#
# ✅ Processed mesh 3416
#
# ✅ Processed mesh 3417
#
# ✅ Processed mesh 3418
#
# ✅ Processed mesh 3419
#
# ✅ Processed mesh 3420
#
# ✅ Processed mesh 3421
#
# ✅ Processed mesh 3422
#
# ✅ Processed mesh 3423
#
# ✅ Processed mesh 3424
#
# ✅ Processed mesh 3425
#
# ✅ Processed mesh 3426
#
# ✅ Processed mesh 3427
#
# ✅ Processed mesh 3428
#
# ✅ Processed mesh 3429
#
# ✅ Processed mesh 3430
#
# ✅ Processed mesh 3431
#
# ✅ Processed mesh 3432
#
# ✅ Processed mesh 3433
#
# ✅ Processed mesh 3434
#
# ✅ Processed mesh 3435
#
# ✅ Processed mesh 3436
#
# ✅ Processed mesh 3437
#
# ✅ Processed mesh 3438
#
# ✅ Processed mesh 3439
#
# ✅ Processed mesh 3440
#
# ✅ Processed mesh 3441
#
# ✅ Processed mesh 3442
#
# ✅ Processed mesh 3443
#
# ✅ Processed mesh 3444
#
# ✅ Processed mesh 3445
#
# ✅ Processed mesh 3446
#
# ✅ Processed mesh 3447
#
# ✅ Processed mesh 3448
#
# ✅ Processed mesh 3449
#
# ✅ Processed mesh 3450
#
# ✅ Processed mesh 3451
#
# ✅ Processed mesh 3452
#
# ✅ Processed mesh 3453
#
# ✅ Processed mesh 3454
#
# ✅ Processed mesh 3455
#
# ✅ Processed mesh 3456
#
# ✅ Processed mesh 3457
#
# ✅ Processed mesh 3458
#
# ✅ Processed mesh 3459
#
# ✅ Processed mesh 3460
#
# ✅ Processed mesh 3461
#
# ✅ Processed mesh 3462
#
# ✅ Processed mesh 3463
#
# ✅ Processed mesh 3464
#
# ✅ Processed mesh 3465
#
# ✅ Processed mesh 3466
#
# ✅ Processed mesh 3467
#
# ✅ Processed mesh 3468
#
# ✅ Processed mesh 3469
#
# ✅ Processed mesh 3470
#
# ✅ Processed mesh 3471
#
# ✅ Processed mesh 3472
#
# ✅ Processed mesh 3473
#
# ✅ Processed mesh 3474
#
# ✅ Processed mesh 3475
#
# ✅ Processed mesh 3476
#
# ✅ Processed mesh 3477
#
# ✅ Processed mesh 3478
#
# ✅ Processed mesh 3479
#
# ✅ Processed mesh 3480
#
# ✅ Processed mesh 3481
#
# ✅ Processed mesh 3482
#
# ✅ Processed mesh 3483
#
# ✅ Processed mesh 3484
#
# ✅ Processed mesh 3485
#
# ✅ Processed mesh 3486
#
# ✅ Processed mesh 3487
#
# ✅ Processed mesh 3488
#
# ✅ Processed mesh 3489
#
# ✅ Processed mesh 3490
#
# ✅ Processed mesh 3491
#
# ✅ Processed mesh 3492
#
# ✅ Processed mesh 3493
#
# ✅ Processed mesh 3494
#
# ✅ Processed mesh 3495
#
# ✅ Processed mesh 3496
#
# ✅ Processed mesh 3497
#
# ✅ Processed mesh 3498
#
# ✅ Processed mesh 3499
#
# ✅ Processed mesh 3500
#
# ✅ Processed mesh 3501
#
# ✅ Processed mesh 3502
#
# ✅ Processed mesh 3503
#
# ✅ Processed mesh 3504
#
# ✅ Processed mesh 3505
#
# ✅ Processed mesh 3506
#
# ✅ Processed mesh 3507
#
# ✅ Processed mesh 3508
#
# ✅ Processed mesh 3509
#
# ✅ Processed mesh 3510
#
# ✅ Processed mesh 3511
#
# ✅ Processed mesh 3512
#
# ✅ Processed mesh 3513
#
# ✅ Processed mesh 3514
#
# ✅ Processed mesh 3515
#
# ✅ Processed mesh 3516
#
# ✅ Processed mesh 3517
#
# ✅ Processed mesh 3518
#
# ✅ Processed mesh 3519
#
# ✅ Processed mesh 3520
#
# ✅ Processed mesh 3521
#
# ✅ Processed mesh 3522
#
# ✅ Processed mesh 3523
#
# ✅ Processed mesh 3524
#
# ✅ Processed mesh 3525
#
# ✅ Processed mesh 3526
#
# ✅ Processed mesh 3527
#
# ✅ Processed mesh 3528
#
# ✅ Processed mesh 3529
#
# ✅ Processed mesh 3530
#
# ✅ Processed mesh 3531
#
# ✅ Processed mesh 3532
#
# ✅ Processed mesh 3533
#
# ✅ Processed mesh 3534
#
# ✅ Processed mesh 3535
#
# ✅ Processed mesh 3536
#
# ✅ Processed mesh 3537
#
# ✅ Processed mesh 3538
#
# ✅ Processed mesh 3539
#
# ✅ Processed mesh 3540
#
# ✅ Processed mesh 3541
#
# ✅ Processed mesh 3542
#
# ✅ Processed mesh 3543
#
# ✅ Processed mesh 3544
#
# ✅ Processed mesh 3545
#
# ✅ Processed mesh 3546
#
# ✅ Processed mesh 3547
#
# ✅ Processed mesh 3548
#
# ✅ Processed mesh 3549
#
# ✅ Processed mesh 3550
#
# ✅ Processed mesh 3551
#
# ✅ Processed mesh 3552
#
# ✅ Processed mesh 3553
#
# ✅ Processed mesh 3554
#
# ✅ Processed mesh 3555
#
# ✅ Processed mesh 3556
#
# ✅ Processed mesh 3557
#
# ✅ Processed mesh 3558
#
# ✅ Processed mesh 3559
#
# ✅ Processed mesh 3560
#
# ✅ Processed mesh 3561
#
# ✅ Processed mesh 3562
#
# ✅ Processed mesh 3563
#
# ✅ Processed mesh 3564
#
# ✅ Processed mesh 3565
#
# ✅ Processed mesh 3566
#
# ✅ Processed mesh 3567
#
# ✅ Processed mesh 3568
#
# ✅ Processed mesh 3569
#
# ✅ Processed mesh 3570
#
# ✅ Processed mesh 3571
#
# ✅ Processed mesh 3572
#
# ✅ Processed mesh 3573
#
# ✅ Processed mesh 3574
#
# ✅ Processed mesh 3575
#
# ✅ Processed mesh 3576
#
# ✅ Processed mesh 3577
#
# ✅ Processed mesh 3578
#
# ✅ Processed mesh 3579
#
# ✅ Processed mesh 3580
#
# ✅ Processed mesh 3581
#
# ✅ Processed mesh 3582
#
# ✅ Processed mesh 3583
#
# ✅ Processed mesh 3584
#
# ✅ Processed mesh 3585
#
# ✅ Processed mesh 3586
#
# ✅ Processed mesh 3587
#
# ✅ Processed mesh 3588
#
# ✅ Processed mesh 3589
#
# ✅ Processed mesh 3590
#
# ✅ Processed mesh 3591
#
# ✅ Processed mesh 3592
#
# ✅ Processed mesh 3593
#
# ✅ Processed mesh 3594
#
# ✅ Processed mesh 3595
#
# ✅ Processed mesh 3596
#
# ✅ Processed mesh 3597
#
# ✅ Processed mesh 3598
#
# ✅ Processed mesh 3599
#
# ✅ Processed mesh 3600
#
# ✅ Processed mesh 3601
#
# ✅ Processed mesh 3602
#
# ✅ Processed mesh 3603
#
# ✅ Processed mesh 3604
#
# ✅ Processed mesh 3605
#
# ✅ Processed mesh 3606
#
# ✅ Processed mesh 3607
#
# ✅ Processed mesh 3608
#
# ✅ Processed mesh 3609
#
# ✅ Processed mesh 3610
#
# ✅ Processed mesh 3611
#
# ✅ Processed mesh 3612
#
# ✅ Processed mesh 3613
#
# ✅ Processed mesh 3614
#
# ✅ Processed mesh 3615
#
# ✅ Processed mesh 3616
#
# ✅ Processed mesh 3617
#
# ✅ Processed mesh 3618
#
# ✅ Processed mesh 3619
#
# ✅ Processed mesh 3620
#
# ✅ Processed mesh 3621
#
# ✅ Processed mesh 3622
#
# ✅ Processed mesh 3623
#
# ✅ Processed mesh 3624
#
# ✅ Processed mesh 3625
#
# ✅ Processed mesh 3626
#
# ✅ Processed mesh 3627
#
# ✅ Processed mesh 3628
#
# ✅ Processed mesh 3629
#
# ✅ Processed mesh 3630
#
# ✅ Processed mesh 3631
#
# ✅ Processed mesh 3632
#
# ✅ Processed mesh 3633
#
# ✅ Processed mesh 3634
#
# ✅ Processed mesh 3635
#
# ✅ Processed mesh 3636
#
# ✅ Processed mesh 3637
#
# ✅ Processed mesh 3638
#
# ✅ Processed mesh 3639
#
# ✅ Processed mesh 3640
#
# ✅ Processed mesh 3641
#
# ✅ Processed mesh 3642
#
# ✅ Processed mesh 3643
#
# ✅ Processed mesh 3644
#
# ✅ Processed mesh 3645
#
# ✅ Processed mesh 3646
#
# ✅ Processed mesh 3647
#
# ✅ Processed mesh 3648
#
# ✅ Processed mesh 3649
#
# ✅ Processed mesh 3650
#
# ✅ Processed mesh 3651
#
# ✅ Processed mesh 3652
#
# ✅ Processed mesh 3653
#
# ✅ Processed mesh 3654
#
# ✅ Processed mesh 3655
#
# ✅ Processed mesh 3656
#
# ✅ Processed mesh 3657
#
# ✅ Processed mesh 3658
#
# ✅ Processed mesh 3659
#
# ✅ Processed mesh 3660
#
# ✅ Processed mesh 3661
#
# ✅ Processed mesh 3662
#
# ✅ Processed mesh 3663
#
# ✅ Processed mesh 3664
#
# ✅ Processed mesh 3665
#
# ✅ Processed mesh 3666
#
# ✅ Processed mesh 3667
#
# ✅ Processed mesh 3668
#
# ✅ Processed mesh 3669
#
# ✅ Processed mesh 3670
#
# ✅ Processed mesh 3671
#
# ✅ Processed mesh 3672
#
# ✅ Processed mesh 3673
#
# ✅ Processed mesh 3674
#
# ✅ Processed mesh 3675
#
# ✅ Processed mesh 3676
#
# ✅ Processed mesh 3677
#
# ✅ Processed mesh 3678
#
# ✅ Processed mesh 3679
#
# ✅ Processed mesh 3680
#
# ✅ Processed mesh 3681
#
# ✅ Processed mesh 3682
#
# ✅ Processed mesh 3683
#
# ✅ Processed mesh 3684
#
# ✅ Processed mesh 3685
#
# ✅ Processed mesh 3686
#
# ✅ Processed mesh 3687
#
# ✅ Processed mesh 3688
#
# ✅ Processed mesh 3689
#
# ✅ Processed mesh 3690
#
# ✅ Processed mesh 3691
#
# ✅ Processed mesh 3692
#
# ✅ Processed mesh 3693
#
# ✅ Processed mesh 3694
#
# ✅ Processed mesh 3695
#
# ✅ Processed mesh 3696
#
# ✅ Processed mesh 3697
#
# ✅ Processed mesh 3698
#
# ✅ Processed mesh 3699
#
# ✅ Processed mesh 3700
#
# ✅ Processed mesh 3701
#
# ✅ Processed mesh 3702
#
# ✅ Processed mesh 3703
#
# ✅ Processed mesh 3704
#
# ✅ Processed mesh 3705
#
# ✅ Processed mesh 3706
#
# ✅ Processed mesh 3707
#
# ✅ Processed mesh 3708
#
# ✅ Processed mesh 3709
#
# ✅ Processed mesh 3710
#
# ✅ Processed mesh 3711
#
# ✅ Processed mesh 3712
#
# ✅ Processed mesh 3713
#
# ✅ Processed mesh 3714
#
# ✅ Processed mesh 3715
#
# ✅ Processed mesh 3716
#
# ✅ Processed mesh 3717
#
# ✅ Processed mesh 3718
#
# ✅ Processed mesh 3719
#
# ✅ Processed mesh 3720
#
# ✅ Processed mesh 3721
#
# ✅ Processed mesh 3722
#
# ✅ Processed mesh 3723
#
# ✅ Processed mesh 3724
#
# ✅ Processed mesh 3725
#
# ✅ Processed mesh 3726
#
# ✅ Processed mesh 3727
#
# ✅ Processed mesh 3728
#
# ✅ Processed mesh 3729
#
# ✅ Processed mesh 3730
#
# ✅ Processed mesh 3731
#
# ✅ Processed mesh 3732
#
# ✅ Processed mesh 3733
#
# ✅ Processed mesh 3734
#
# ✅ Processed mesh 3735
#
# ✅ Processed mesh 3736
#
# ✅ Processed mesh 3737
#
# ✅ Processed mesh 3738
#
# ✅ Processed mesh 3739
#
# ✅ Processed mesh 3740
#
# ✅ Processed mesh 3741
#
# ✅ Processed mesh 3742
#
# ✅ Processed mesh 3743
#
# ✅ Processed mesh 3744
#
# ✅ Processed mesh 3745
#
# ✅ Processed mesh 3746
#
# ✅ Processed mesh 3747
#
# ✅ Processed mesh 3748
#
# ✅ Processed mesh 3749
#
# ✅ Processed mesh 3750
#
# ✅ Processed mesh 3751
#
# ✅ Processed mesh 3752
#
# ✅ Processed mesh 3753
#
# ✅ Processed mesh 3754
#
# ✅ Processed mesh 3755
#
# ✅ Processed mesh 3756
#
# ✅ Processed mesh 3757
#
# ✅ Processed mesh 3758
#
# ✅ Processed mesh 3759
#
# ✅ Processed mesh 3760
#
# ✅ Processed mesh 3761
#
# ✅ Processed mesh 3762
#
# ✅ Processed mesh 3763
#
# ✅ Processed mesh 3764
#
# ✅ Processed mesh 3765
#
# ✅ Processed mesh 3766
#
# ✅ Processed mesh 3767
#
# ✅ Processed mesh 3768
#
# ✅ Processed mesh 3769
#
# ✅ Processed mesh 3770
#
# ✅ Processed mesh 3771
#
# ✅ Processed mesh 3772
#
# ✅ Processed mesh 3773
#
# ✅ Processed mesh 3774
#
# ✅ Processed mesh 3775
#
# ✅ Processed mesh 3776
#
# ✅ Processed mesh 3777
#
# ✅ Processed mesh 3778
#
# ✅ Processed mesh 3779
#
# ✅ Processed mesh 3780
#
# ✅ Processed mesh 3781
#
# ✅ Processed mesh 3782
#
# ✅ Processed mesh 3783
#
# ✅ Processed mesh 3784
#
# ✅ Processed mesh 3785
#
# ✅ Processed mesh 3786
#
# ✅ Processed mesh 3787
#
# ✅ Processed mesh 3788
#
# ✅ Processed mesh 3789
#
# ✅ Processed mesh 3790
#
# ✅ Processed mesh 3791
#
# ✅ Processed mesh 3792
#
# ✅ Processed mesh 3793
#
# ✅ Processed mesh 3794
#
# ✅ Processed mesh 3795
#
# ✅ Processed mesh 3796
#
# ✅ Processed mesh 3797
#
# ✅ Processed mesh 3798
#
# ✅ Processed mesh 3799
#
# ✅ Processed mesh 3800
#
# ✅ Processed mesh 3801
#
# ✅ Processed mesh 3802
#
# ✅ Processed mesh 3803
#
# ✅ Processed mesh 3804
#
# ✅ Processed mesh 3805
#
# ✅ Processed mesh 3806
#
# ✅ Processed mesh 3807
#
# ✅ Processed mesh 3808
#
# ✅ Processed mesh 3809
#
# ✅ Processed mesh 3810
#
# ✅ Processed mesh 3811
#
# ✅ Processed mesh 3812
#
# ✅ Processed mesh 3813
#
# ✅ Processed mesh 3814
#
# ✅ Processed mesh 3815
#
# ✅ Processed mesh 3816
#
# ✅ Processed mesh 3817
#
# ✅ Processed mesh 3818
#
# ✅ Processed mesh 3819
#
# ✅ Processed mesh 3820
#
# ✅ Processed mesh 3821
#
# ✅ Processed mesh 3822
#
# ✅ Processed mesh 3823
#
# ✅ Processed mesh 3824
#
# ✅ Processed mesh 3825
#
# ✅ Processed mesh 3826
#
# ✅ Processed mesh 3827
#
# ✅ Processed mesh 3828
#
# ✅ Processed mesh 3829
#
# ✅ Processed mesh 3830
#
# ✅ Processed mesh 3831
#
# ✅ Processed mesh 3832
#
# ✅ Processed mesh 3833
#
# ✅ Processed mesh 3834
#
# ✅ Processed mesh 3835
#
# ✅ Processed mesh 3836
#
# ✅ Processed mesh 3837
#
# ✅ Processed mesh 3838
#
# ✅ Processed mesh 3839
#
# ✅ Processed mesh 3840
#
# ✅ Processed mesh 3841
#
# ✅ Processed mesh 3842
#
# ✅ Processed mesh 3843
#
# ✅ Processed mesh 3844
#
# ✅ Processed mesh 3845
#
# ✅ Processed mesh 3846
#
# ✅ Processed mesh 3847
#
# ✅ Processed mesh 3848
#
# ✅ Processed mesh 3849
#
# ✅ Processed mesh 3850
#
# ✅ Processed mesh 3851
#
# ✅ Processed mesh 3852
#
# ✅ Processed mesh 3853
#
# ✅ Processed mesh 3854
#
# ✅ Processed mesh 3855
#
# ✅ Processed mesh 3856
#
# ✅ Processed mesh 3857
#
# ✅ Processed mesh 3858
#
# ✅ Processed mesh 3859
#
# ✅ Processed mesh 3860
#
# ✅ Processed mesh 3861
#
# ✅ Processed mesh 3862
#
# ✅ Processed mesh 3863
#
# ✅ Processed mesh 3864
#
# ✅ Processed mesh 3865
#
# ✅ Processed mesh 3866
#
# ✅ Processed mesh 3867
#
# ✅ Processed mesh 3868
#
# ✅ Processed mesh 3869
#
# ✅ Processed mesh 3870
#
# ✅ Processed mesh 3871
#
# ✅ Processed mesh 3872
#
# ✅ Processed mesh 3873
#
# ✅ Processed mesh 3874
#
# ✅ Processed mesh 3875
#
# ✅ Processed mesh 3876
#
# ✅ Processed mesh 3877
#
# ✅ Processed mesh 3878
#
# ✅ Processed mesh 3879
#
# ✅ Processed mesh 3880
#
# ✅ Processed mesh 3881
#
# ✅ Processed mesh 3882
#
# ✅ Processed mesh 3883
#
# ✅ Processed mesh 3884
#
# ✅ Processed mesh 3885
#
# ✅ Processed mesh 3886
#
# ✅ Processed mesh 3887
#
# ✅ Processed mesh 3888
#
# ✅ Processed mesh 3889
#
# ✅ Processed mesh 3890
#
# ✅ Processed mesh 3891
#
# ✅ Processed mesh 3892
#
# ✅ Processed mesh 3893
#
# ✅ Processed mesh 3894
#
# ✅ Processed mesh 3895
#
# ✅ Processed mesh 3896
#
# ✅ Processed mesh 3897
#
# ✅ Processed mesh 3898
#
# ✅ Processed mesh 3899
#
# ✅ Processed mesh 3900
#
# ✅ Processed mesh 3901
#
# ✅ Processed mesh 3902
#
# ✅ Processed mesh 3903
#
# ✅ Processed mesh 3904
#
# ✅ Processed mesh 3905
#
# ✅ Processed mesh 3906
#
# ✅ Processed mesh 3907
#
# ✅ Processed mesh 3908
#
# ✅ Processed mesh 3909
#
# ✅ Processed mesh 3910
#
# ✅ Processed mesh 3911
#
# ✅ Processed mesh 3912
#
# ✅ Processed mesh 3913
#
# ✅ Processed mesh 3914
#
# ✅ Processed mesh 3915
#
# ✅ Processed mesh 3916
#
# ✅ Processed mesh 3917
#
# ✅ Processed mesh 3918
#
# ✅ Processed mesh 3919
#
# ✅ Processed mesh 3920
#
# ✅ Processed mesh 3921
#
# ✅ Processed mesh 3922
#
# ✅ Processed mesh 3923
#
# ✅ Processed mesh 3924
#
# ✅ Processed mesh 3925
#
# ✅ Processed mesh 3926
#
# ✅ Processed mesh 3927
#
# ✅ Processed mesh 3928
#
# ✅ Processed mesh 3929
#
# ✅ Processed mesh 3930
#
# ✅ Processed mesh 3931
#
# ✅ Processed mesh 3932
#
# ✅ Processed mesh 3933
#
# ✅ Processed mesh 3934
#
# ✅ Processed mesh 3935
#
# ✅ Processed mesh 3936
#
# ✅ Processed mesh 3937
#
# ✅ Processed mesh 3938
#
# ✅ Processed mesh 3939
#
# ✅ Processed mesh 3940
#
# ✅ Processed mesh 3941
#
# ✅ Processed mesh 3942
#
# ✅ Processed mesh 3943
#
# ✅ Processed mesh 3944
#
# ✅ Processed mesh 3945
#
# ✅ Processed mesh 3946
#
# ✅ Processed mesh 3947
#
# ✅ Processed mesh 3948
#
# ✅ Processed mesh 3949
#
# ✅ Processed mesh 3950
#
# ✅ Processed mesh 3951
#
# ✅ Processed mesh 3952
#
# ✅ Processed mesh 3953
#
# ✅ Processed mesh 3954
#
# ✅ Processed mesh 3955
#
# ✅ Processed mesh 3956
#
# ✅ Processed mesh 3957
#
# ✅ Processed mesh 3958
#
# ✅ Processed mesh 3959
#
# ✅ Processed mesh 3960
#
# ✅ Processed mesh 3961
#
# ✅ Processed mesh 3962
#
# ✅ Processed mesh 3963
#
# ✅ Processed mesh 3964
#
# ✅ Processed mesh 3965
#
# ✅ Processed mesh 3966
#
# ✅ Processed mesh 3967
#
# ✅ Processed mesh 3968
#
# ✅ Processed mesh 3969
#
# ✅ Processed mesh 3970
#
# ✅ Processed mesh 3971
#
# ✅ Processed mesh 3972
#
# ✅ Processed mesh 3973
#
# ✅ Processed mesh 3974
#
# ✅ Processed mesh 3975
#
# ✅ Processed mesh 3976
#
# ✅ Processed mesh 3977
#
# ✅ Processed mesh 3978
#
# ✅ Processed mesh 3979
#
# ✅ Processed mesh 3980
#
# ✅ Processed mesh 3981
#
# ✅ Processed mesh 3982
#
# ✅ Processed mesh 3983
#
# ✅ Processed mesh 3984
#
# ✅ Processed mesh 3985
#
# ✅ Processed mesh 3986
#
# ✅ Processed mesh 3987
#
# ✅ Processed mesh 3988
#
# ✅ Processed mesh 3989
#
# ✅ Processed mesh 3990
#
# ✅ Processed mesh 3991
#
# ✅ Processed mesh 3992
#
# ✅ Processed mesh 3993
#
# ✅ Processed mesh 3994
#
# ✅ Processed mesh 3995
#
# ✅ Processed mesh 3996
#
# ✅ Processed mesh 3997
#
# ✅ Processed mesh 3998
#
# ✅ Processed mesh 3999
#
# ✅ Saved dataset to D:/ML4pmg/Data_Large4/mesh_features.csv
# Dataset built in 15347.87 seconds

# %%
(t1-t0)/ 60 /60 # Convert to hours
# Out:
# 4.263296890788608

# %%
df = pd.read_csv("D:/ML4pmg/Data_Large4/mesh_features.csv")

# %%
df.describe()
# Out:
#            mesh_id     n_elements       n_nodes  n_fractures    area_mean  \
# count  4000.000000    4000.000000   4000.000000  4000.000000  4000.000000
# mean   1999.500000   18521.958250   9363.844250    50.055250     0.000060
# std    1154.844867    6435.699304   3227.146742     6.117398     0.000020
# min       0.000000    6250.000000   3202.000000    40.000000     0.000009
# 25%     999.750000   14018.750000   7114.750000    45.000000     0.000046
# 50%    1999.500000   17805.500000   9000.000000    50.000000     0.000056
# 75%    2999.250000   21766.500000  10991.250000    55.000000     0.000071
# max    3999.000000  112822.000000  56528.000000    60.000000     0.000160
#
#         area_median     area_std     area_5pct   area_95pct      area_min  \
# count  4.000000e+03  4000.000000  4.000000e+03  4000.000000  4.000000e+03
# mean   2.141441e-05     0.000110  3.103453e-07     0.000244  6.089272e-09
# std    1.125918e-05     0.000030  4.116788e-07     0.000071  1.911691e-08
# min    7.507928e-09     0.000037  1.249292e-11     0.000045  3.548256e-17
# 25%    1.372020e-05     0.000087  7.092088e-08     0.000192  1.463179e-10
# 50%    1.929655e-05     0.000105  1.768420e-07     0.000231  9.420736e-10
# 75%    2.692520e-05     0.000128  3.891183e-07     0.000288  4.258929e-09
# max    9.649305e-05     0.000259  7.105846e-06     0.000563  4.165506e-07
#
#        ...  length_95pct   length_min   length_max  orientation_mean  \
# count  ...   4000.000000  4000.000000  4000.000000       4000.000000
# mean   ...      1.853203     0.081403     3.989039          0.344077
# std    ...      0.500347     0.044172     2.419019          0.294489
# min    ...      1.033565     0.001228     1.130070         -0.754371
# 25%    ...      1.492572     0.048746     2.500382          0.143799
# 50%    ...      1.743742     0.074667     3.352428          0.344516
# 75%    ...      2.092117     0.107894     4.711690          0.546078
# max    ...      5.030458     0.323586    37.347434          1.417098
#
#        orientation_median  orientation_std  orientation_5pct  \
# count         4000.000000      4000.000000       4000.000000
# mean             0.951395         2.005502         -2.826083
# std              0.358863         0.125704          0.143715
# min             -1.834667         1.360317         -3.123601
# 25%              0.811139         1.930246         -2.930814
# 50%              0.976157         2.014918         -2.841455
# 75%              1.152465         2.093026         -2.738223
# max              1.960651         2.361802         -1.993027
#
#        orientation_95pct  orientation_min  orientation_max
# count        4000.000000      4000.000000      4000.000000
# mean            2.808525        -3.043726         3.043652
# std             0.152729         0.090784         0.094755
# min             1.969846        -3.141499         2.317778
# 25%             2.715674        -3.112460         3.003127
# 50%             2.826385        -3.070549         3.071396
# 75%             2.921292        -3.002360         3.112218
# max             3.125465        -2.586076         3.141591
#
# [8 rows x 110 columns]

# %% [markdown]
# ### Update with Convergence Patterns and Pattern IDs

# %%
def annotate_with_convergence_patterns(dataset_csv, output_csv):
    df = pd.read_csv(dataset_csv)

    # Extract convergence columns (assumed to start with 'y_conv_')
    y_conv_cols = [col for col in df.columns if col.startswith('y_conv_')]
    if not y_conv_cols:
        raise ValueError("No convergence columns (y_conv_*) found in dataset!")

    # Step 1 — Build convergence pattern string
    df['convergence_pattern'] = df[y_conv_cols].astype(int).astype(str).agg(''.join, axis=1)

    # Step 2 — Count frequencies of unique patterns
    pattern_counts = df['convergence_pattern'].value_counts()

    # Step 3 — Assign pattern_id by frequency (most common is 0)
    pattern_to_id = {pattern: idx for idx, pattern in enumerate(pattern_counts.index)}
    df['pattern_id'] = df['convergence_pattern'].map(pattern_to_id)

    # Step 4 — Save updated dataset
    df.to_csv(output_csv, index=False)
    print(f"✅ Annotated dataset saved to {output_csv}")
    print("\nTop patterns with counts:")
    print(pattern_counts.head(10))

    return df, pattern_counts

# %%
updated_df, pattern_counts = annotate_with_convergence_patterns(
    dataset_csv="D:/ML4pmg/Data_Large4/mesh_features.csv",
    output_csv="D:/ML4pmg/Data_Large4/mesh_features_annotated.csv"
)
# Out:
# ✅ Annotated dataset saved to D:/ML4pmg/Data_Large4/mesh_features_annotated.csv
#
# Top patterns with counts:
# convergence_pattern
# 000000000000000000    1400
# 000000100111000001     761
# 000000000001000001     591
# 000001100111000001     411
# 000000100110000000     276
# 000001100111100111     209
# 000000100111100111      93
# 000000000001000000      90
# 000001000001000001      62
# 000000100111000000      33
# Name: count, dtype: int64

# %%
print(pattern_counts.head(15))
# Out:
# convergence_pattern
# 000000000000000000    1400
# 000000100111000001     761
# 000000000001000001     591
# 000001100111000001     411
# 000000100110000000     276
# 000001100111100111     209
# 000000100111100111      93
# 000000000001000000      90
# 000001000001000001      62
# 000000100111000000      33
# 000000100110000001      29
# 000000000000000001      26
# 000000100110100110      16
# 000000100110100111       3
# Name: count, dtype: int64

# %% [markdown]
# ### Make balanced dataset

# %%
def create_balanced_dataset_simple(df, top_k_patterns=6, samples_per_pattern=100, random_state=42, shuffle=True):
    balanced_parts = []

    for pattern_id in range(top_k_patterns):
        group = df[df['pattern_id'] == pattern_id]
        if len(group) >= samples_per_pattern:
            sampled = group.sample(n=samples_per_pattern, random_state=random_state)
        else:
            sampled = group.sample(n=samples_per_pattern, replace=True, random_state=random_state)
        balanced_parts.append(sampled)

    balanced_df = pd.concat(balanced_parts, ignore_index=True)

    if shuffle:
        balanced_df = balanced_df.sample(frac=1.0, random_state=random_state).reset_index(drop=True)

    print(f"✅ Balanced dataset with {samples_per_pattern} samples for each of {top_k_patterns} patterns.")

    return balanced_df

# %%
df = pd.read_csv("D:/ML4pmg/Data_Large4/mesh_features_annotated.csv")
balanced_df = create_balanced_dataset_simple(df, top_k_patterns=8, samples_per_pattern=200)
balanced_df.to_csv("D:/ML4pmg/Data_Large4/balanced_mesh_features.csv", index=False)
# Out:
# ✅ Balanced dataset with 200 samples for each of 8 patterns.

# %% [markdown]
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# See `MLmodels.ipynb` for RandomForest Classification and Regression
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
df.columns
# Out:
# Index(['mesh_name', 'mesh_id', 'n_elements', 'n_nodes', 'n_fractures',
#        'area_mean', 'area_median', 'area_std', 'area_5pct', 'area_95pct',
#        ...
#        'length_max', 'orientation_mean', 'orientation_median',
#        'orientation_std', 'orientation_5pct', 'orientation_95pct',
#        'orientation_min', 'orientation_max', 'convergence_pattern',
#        'pattern_id'],
#       dtype='object', length=113)
